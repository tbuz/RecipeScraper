# %% [markdown]
# # Creating FastText word embeddings for recipe titles
#
# We can use FastText to create word vectors for the words that are used in recipe titles.
# With the skipgram model using character n-grams, FastText can be useful to rank semantically close words with a similar word vector, even if they are written slightly differently.
# Thus, this vector representation works with typos as well.
#
# First, we need to generate a corpus from the recipe dataset and then train the FastText model on it:

# %%
import json

with open('data/kochbar_03.json') as data_file:    
    kochbar = json.load(data_file)

# %%
# How does the data look?
kochbar[0]
# Out:
# {'avg_rating': '4,83',
#  'calories': '933 (223)',
#  'clicks': '101092',
#  'comment_number': '59',
#  'date': '26.07.2009',
#  'difficulty': 'leicht',
#  'favorites': '925',
#  'ingredients': '500   gr. Hackfleisch    3    Zucchini    1   Btl. Spätzle, fertige   Salz, Pfeffer   Knoblauchzehe    1   Pck. Kräuterfrischkäse, 200gr.    1   Becher süße Sahne    2   Eßl. frische Petersilie, gehackt   Salz, Knoblauchgranulat    4    Eier',
#  'name': 'Zucchini-Hackauflauf mit Frischkäse und Spätzle ',
#  'number_votes': '141',
#  'preparation': '    1  Das  Hackfleisch mit etwas Margarine in der Pfanne krümelig anbraten.\rZucchini waschen, halbieren und mit einem Teelöffel die Kerne entfernen, dann in Scheibchen schneiden. dazugeben und kurz mitbraten. Salzen und Pfeffern,  Knobi auspressen, dazugeben und abschmecken.2  Alles in eine Auflaufform geben und die Spätzle unterheben.\rDen Kräuterfrischkäse mit der Sahne und den Eiern glattrühren, die gehackte Petersilie mit einrühren. Mit Salz und Pfeffer und Knoblauchgranulat abschmecken. alles über die Hackfleischmischung geben.3  Im vorgeheizten Backofen, mittl. Schiene, auf 200 Grad ca. 30 Min überbacken, bis die obere Schicht leicht bräunlich wird.  ',
#  'price': '€ ',
#  'subtitle': 'guter Appetit-Auflauf, der auch mit gekochten Kartoffelwürfeln gut schmeckt',
#  'time_hrs': None,
#  'time_mins': '45',
#  'user': 'romantica'}

# %%
text_file = open("data/stopwords.txt", "r", encoding = "ISO-8859-1")
stopwords  = text_file.readlines()
for i in range(len(stopwords)):
    stopwords[i] = stopwords[i].replace('\n','')

more_stopwords = ('Art', 'a', 'la', 'de', 'á', 'à', 'ohne', 'mal', 'lecker', 'Mein', 'dazu', 
                  'ala', 'au', 'alla', 'ganz', 'schnelle', 'al', 'di', 'Die', 'Der', 'Das', 
                  'MIT', 'Mit', 'a’la', 'Ein', 'so', 'u', 'e', 'E', 'nur', 'D', 'A', 'Co', 
                  'I', 'um', 'ihn', 'and', 'Aus', 'II', 'Nr', 'Style', 'gut', 'ca', 'UND', 'con', 
                  'NUR', 'to', 'go', 'fettarm', 'Low', 'Carb', 'Food', 'original', 'Original', 
                  'super', 'sooo')
for w in more_stopwords:
    stopwords.append(w)
    
stopwords
# Out:
# ['aber',
#  'als',
#  'am',
#  'an',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'dadurch',
#  'daher',
#  'darum',
#  'das',
#  'daß',
#  'dass',
#  'dein',
#  'deine',
#  'dem',
#  'den',
#  'der',
#  'des',
#  'dessen',
#  'deshalb',
#  'die',
#  'dies',
#  'dieser',
#  'dieses',
#  'doch',
#  'dort',
#  'du',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'er',
#  'es',
#  'euer',
#  'eure',
#  'für',
#  'hatte',
#  'hatten',
#  'hattest',
#  'hattet',
#  'hier',
#  'hinter',
#  'ich',
#  'ihr',
#  'ihre',
#  'im',
#  'in',
#  'ist',
#  'ja',
#  'jede',
#  'jedem',
#  'jeden',
#  'jeder',
#  'jedes',
#  'jener',
#  'jenes',
#  'jetzt',
#  'kann',
#  'kannst',
#  'können',
#  'könnt',
#  'machen',
#  'mein',
#  'meine',
#  'mit',
#  'muß',
#  'mußt',
#  'musst',
#  'müssen',
#  'müßt',
#  'nach',
#  'nachdem',
#  'nein',
#  'nicht',
#  'nun',
#  'oder',
#  'seid',
#  'sein',
#  'seine',
#  'sich',
#  'sie',
#  'sind',
#  'soll',
#  'sollen',
#  'sollst',
#  'sollt',
#  'sonst',
#  'soweit',
#  'sowie',
#  'und',
#  'unser',
#  'unsere',
#  'unter',
#  'vom',
#  'von',
#  'vor',
#  'wann',
#  'warum',
#  'was',
#  'weiter',
#  'weitere',
#  'wenn',
#  'wer',
#  'werde',
#  'werden',
#  'werdet',
#  'weshalb',
#  'wie',
#  'wieder',
#  'wieso',
#  'wir',
#  'wird',
#  'wirst',
#  'wo',
#  'woher',
#  'wohin',
#  'zu',
#  'zum',
#  'zur',
#  'über',
#  'Art',
#  'a',
#  'la',
#  'de',
#  'á',
#  'à',
#  'ohne',
#  'mal',
#  'lecker',
#  'Mein',
#  'dazu',
#  'ala',
#  'au',
#  'alla',
#  'ganz',
#  'schnelle',
#  'al',
#  'di',
#  'Die',
#  'Der',
#  'Das',
#  'MIT',
#  'Mit',
#  'a’la',
#  'Ein',
#  'so',
#  'u',
#  'e',
#  'E',
#  'nur',
#  'D',
#  'A',
#  'Co',
#  'I',
#  'um',
#  'ihn',
#  'and',
#  'Aus',
#  'II',
#  'Nr',
#  'Style',
#  'gut',
#  'ca',
#  'UND',
#  'con',
#  'NUR',
#  'to',
#  'go',
#  'fettarm',
#  'Low',
#  'Carb',
#  'Food',
#  'original',
#  'Original',
#  'super',
#  'sooo']

# %%
# we need to clean the titles from characters, stopwords, etc.
titlelist = []
for i in range(len(kochbar)):
    title = kochbar[i]['name']
    for char in ['"','-','=','!','(',')','.','♥',',',':','~','„','“','/','–','&','+',';','*','☆']:
        title = title.replace(char,' ')
    tmp_list = list(filter(None, title.split(" ")))   # filter empty elements
    for stop in stopwords:
        tmp_list = list(filter(lambda k: stop != k, tmp_list))  # filter stopwords
    titlelist.append(tmp_list) 
titlelist
# Out:
# [['Zucchini', 'Hackauflauf', 'Frischkäse', 'Spätzle'],
#  ['Japanischer', 'Soufflé', 'Käsekuchen'],
#  ['Chili', 'Carne', 'Spezial'],
#  ['Kartoffelgratin', 'klassisch'],
#  ['Schnellste', 'Bienenstich'],
#  ['Pfannkuchen', 'Grundrezept'],
#  ['Eierlikörkugeln'],
#  ['Grundrezept', 'Muffins'],
#  ['Käsesuppe', 'Hackfleisch', 'Porree'],
#  ['Amerikanische', 'Pancakes'],
#  ['Allerbester', 'Käsekuchen'],
#  ['Nutella', 'Ecken', 'Banane'],
#  ['Bruschetta', 'Tomaten'],
#  ['Raffaello', 'Pralinen'],
#  ['Spaghetti', 'Bolognese'],
#  ['Pfannkuchen'],
#  ['Carbonara', 'Rezept', 'Calabrien', 'Sahne'],
#  ['American', 'Brownies'],
#  ['Pizza', 'Schnecken'],
#  ['Flammkuchen', 'Schneller', 'Flammkuchen', 'Hefe'],
#  ['Baileys', 'Muffins'],
#  ['Knusprige', 'Knoblauch', 'Kartoffeln'],
#  ['Nudelsalat', 'Hausfrauen'],
#  ['Überbackene', 'Ofen', 'Kartoffeln', 'Cheddar', 'Hähnchen'],
#  ['Schneller', 'Nudelauflauf'],
#  ['Kartoffelsuppe', 'Würstchen'],
#  ['Pizza', 'Waffeln'],
#  ['Käsespätzle'],
#  ['Schichtsalat'],
#  ['Allerbester', 'Rhabarberkuchen'],
#  ['Kritharaki', 'griechischer', 'Nudelsalat'],
#  ['2', 'Zutaten', 'Schokoladen', 'Kuchen'],
#  ['HUGO', 'Aperitif', 'Südtirol', 'leicht', 'spritzig'],
#  ['Knusprige', 'Pizza'],
#  ['Gebackene', 'Banane', 'honig'],
#  ['KÄSEKUCHEN'],
#  ['Lasagne', 'Pfanne'],
#  ['Blätterteig', 'Quarktaschen'],
#  ['Heidelbeer', 'Mascarpone', 'Kuchen'],
#  ['Quarkbällchen'],
#  ['Tortellini', 'Auflauf'],
#  ['Nudelsalat', 'italienische', 'Honig', 'Senf', 'Dressing'],
#  ['Zucchini', 'Hackfleisch', 'Auflauf', 'Eilige'],
#  ['Zwiebel', 'Sahne', 'Schnitzel'],
#  ['Fingerfood', 'Schafskäsezigarren'],
#  ['Schnittiger', 'Hugo'],
#  ['Elsässer', 'Rahmkuchen'],
#  ['Burger'],
#  ['Party', 'Buletten'],
#  ['Ungarisches', 'Gulasch', 'meiner', 'Tante', 'Ungarn'],
#  ['Nutellakuchen', 'Tasse'],
#  ['Hackbällchen', 'Tomatensoße', 'überbacken'],
#  ['Schnitzelpfanne'],
#  ['Schokokuchen', 'flüssigem', 'Kern'],
#  ['Käsekuchen', 'Boden', 'Angerührt', 'drei', 'Minuten'],
#  ['Partysuppe', 'Pizzasuppe'],
#  ['Pizzaschnecken', 'Weight', 'Watchers'],
#  ['Spaghetti', 'Amatriciana'],
#  ['Gebratene', 'Nudeln'],
#  ['Hackbraten', 'Bacon', 'Mantel', 'Ofenkartoffeln'],
#  ['Sonntagsbrötchen'],
#  ['Fingerfood', 'Party'],
#  ['Zart', 'fluffige', 'Kohlrouladen', 'Backofen'],
#  ['Schokokuchen', 'Großmutters'],
#  ['GRATIN', 'Brokkoli', 'Kartoffel', 'Auflauf'],
#  ['Cheescake', 'Muffins'],
#  ['Apfel', 'Crumble'],
#  ['Waffeln', 'Vanilletraum'],
#  ['Apfelrose', 'Küchlein'],
#  ['Regenbogen', 'Kuchen', 'Backen'],
#  ['edler', 'mediteraner', 'Nudelsalat', 'Grillen'],
#  ['Pasta', 'Parmesansoße', 'Lachs', 'Erbsen'],
#  ['Buntes', 'Pfannengemüse', 'knusprigen', 'Hähnchenfiletmedaillons'],
#  ['Hühnerfrikassee', 'klassisch'],
#  ['Chili', 'Carne'],
#  ['Bagracsgulyas', 'Kesselgulasch'],
#  ['Gemüsetortilla'],
#  ['Vanille', 'Zauberkuchen'],
#  ['Fingerfood', 'Pizzabällchen'],
#  ['Fingerfood', 'vier', 'Rezepte'],
#  ['Easy', 'Käsezupfbrot'],
#  ['Schichtsalat', 'Tomate', 'Mozzarella', 'Honig', 'Balsamico', 'Dressing'],
#  ['Deftiger', 'Auflauf'],
#  ['Bunter', 'Nudelsalat', 'Weight', 'Watchers'],
#  ['Berliner', 'Currywurst', 'Currysauce', 'Brötchen'],
#  ['Nutella', 'Lasagne'],
#  ['Erdbeermojito', 'Bowle'],
#  ['Apfelkuchen', 'Streusel'],
#  ['Spaghetti', 'Tomaten', 'Blattspinat', 'Pinienkernen'],
#  ['Spaghetti', 'bolognese'],
#  ['Hackfleisch', 'Käse', 'Suppe', 'Gemüse'],
#  ['Brot'],
#  ['Alle', 'mögen', 'Nudelsalat'],
#  ['Geflügel', 'Hähnchengeschnetzeltes', 'Gorgonzola', 'Rahm', 'Schupfnudeln'],
#  ['Gefüllte', 'Paprika', 'Hackfleisch', 'Reis', 'Füllung'],
#  ['Hähnchen', 'Curry', 'Reisbandnudeln'],
#  ['Italienischer', 'Nudelsalat', '‚to', 'go‘'],
#  ['Gemüse', 'Auflauf', 'Fleischwurst'],
#  ['Nudelauflauf', 'Hackbällchen'],
#  ['Butterplätzchen'],
#  ['Pizza', 'Margherita'],
#  ['Allerbeste', 'Double', 'Chocolate', 'Cheese', 'Muffins'],
#  ['Saftiger', 'Marmorkuchen'],
#  ['Blueberry', 'Cheesecake', 'Backen'],
#  ['Leichter', 'Wirsing', 'Eintopf'],
#  ['Bananen', 'Schokoladen', 'Blechkuchen'],
#  ['Schwedischer', 'Schokoladenkuchen'],
#  ['Tomatensuppe', 'Feta', 'Würfelchen'],
#  ['Brezenknödel'],
#  ['Quarkbrötchen', 'Kohlenhydrate'],
#  ['Blechfleisch'],
#  ['Cannelloni'],
#  ['Zucchini', 'Möhren', 'Krusti', 'Frühlingsquark'],
#  ['Erbseneintopf'],
#  ['Hefe', 'Grundrezept', 'PIZZA', 'italienisch'],
#  ['Gemüserolle'],
#  ['Kokosmakronen'],
#  ['Fingerfood', 'Lachsröllchen'],
#  ['Blätterteigtaschen'],
#  ['Affenkuchen'],
#  ['Überbackene', 'Garnelen'],
#  ['Easy', 'Cheesy'],
#  ['Blumenkohl', 'Käse', 'Suppe'],
#  ['Kartoffelsuppe'],
#  ['Spargelcremesuppe', 'Von', 'Peter', 'Zens', 'Brühl'],
#  ['Karotten', 'Ingwer', 'Rösti'],
#  ['Omas', 'Apfelkuchen'],
#  ['Crème', 'brûlée'],
#  ['Mediteraner', 'Hack', 'Auflauf', 'Schafskäse', 'Feta'],
#  ['French', 'Toast', 'Roll', 'Ups'],
#  ['beste', 'LASAGNE', 'Welt'],
#  ['15', 'Minuten', 'Super', 'Cheesecake'],
#  ['Pizza', 'Suppe'],
#  ['Quarkkäulchen'],
#  ['Kekse', 'Plätzchen', 'Vanillekekse', 'Schokokekse'],
#  ['Zebra', 'Käsekuchen', 'Boden'],
#  ['neue', 'Wundersuppe', 'Abnehmen'],
#  ['Kartoffelgratin', 'Omelett', 'Muffinform'],
#  ['Kürbissuppe', 'Kokosmilch'],
#  ['Erdbeer', 'Tiramisu'],
#  ['Sauce', 'Hollandaise'],
#  ['Snack', 'Karotten', 'Pommes', 'Parmesan', 'Chili', 'Knoblauch', 'Dip'],
#  ['Weihnachtsplätzchen', 'Zimtsterne'],
#  ['Winterlich', 'Weihnachtlich', 'Eierkuchen', 'Mozart'],
#  ['Dreierlei', 'Kekse', 'Teig'],
#  ['Zebratorte'],
#  ['Spaghetti', 'Bolognese'],
#  ['Zwiebelkuchen'],
#  ['Bananen', 'Joghurt', 'Muffins'],
#  ['Schinken', 'Nudeln', 'Mozzarella'],
#  ['Zürcher', 'Geschnetzeltes'],
#  ['Apfel', 'Küchlein'],
#  ['Apfeltaschen', 'Sandwichmaker'],
#  ['Dip´s', 'Saucen', 'Aioli'],
#  ['Rindergulasch',
#   'Sophia',
#   'Wollersheim',
#   'verrät',
#   'Lieblingsgericht',
#   'Rindergulasch',
#   'zubereitet'],
#  ['Schwäbischer', 'Kartoffelsalat'],
#  ['Gyros', 'Auflauf'],
#  ['Rucola', 'Pesto', 'Nudelsalat'],
#  ['Nudeln', 'Tunfisch', 'Tomatensoße'],
#  ['Pita', 'Hähnchen', 'Tzaziki', 'Salat'],
#  ['Fetastangen'],
#  ['Gebratene', 'Paprika', 'Mozzarella'],
#  ['Bunte', 'Lachs', 'Frischkäse', 'Rolle'],
#  ['Absolut', 'leckerer', 'Blaubeerkuchen'],
#  ['Weihnachtsmarkt', 'Champignons'],
#  ['Fluffiger', 'Kaiserschmarrn'],
#  ['Grillen', 'Hähnchen', 'Ananasspieße', 'Curry', 'Honig', 'Marinade'],
#  ['Plätzchen', 'Saftige', 'Nusswürfel', 'zwei', 'Schichten'],
#  ['LowCarb', 'Spiegelei', 'Speck'],
#  ['Gänsekeulen', 'Omas', 'Zeiten'],
#  ['Putengeschnetzeltes', 'Champignon', 'Rahm', 'Soße'],
#  ['Lachslasagne', 'Spinat', 'Schafskäse'],
#  ['After', 'Eight', 'Muffin'],
#  ['Kohlrouladen'],
#  ['Milchschnitten', 'Schnitten'],
#  ['Lahmacun', 'Wasser', 'lauwarm'],
#  ['Nudel', 'Bolognese', 'Auflauf'],
#  ['Kartoffelsuppe', 'Debreziner'],
#  ['Gratinierte', 'Linguine', 'Hähnchenbrust', 'Weight', 'Watchers'],
#  ['Apfelkuchen', 'sehr', 'fein'],
#  ['Tiramisu', 'Weight', 'Watchers'],
#  ['Spinat', 'Lasagne'],
#  ['Mozzarella', 'Taschen'],
#  ['Tapas', 'Fingerfood', 'Bärlauch', 'Champignon'],
#  ['Omas', 'Eierlikör', 'Rezept', 'Videoanleitung'],
#  ['Pfannkuchen', 'Grundrezept'],
#  ['Annis', 'Nudelauflauf'],
#  ['Pfundstopf'],
#  ['Geheim', 'Sauce', 'BIG', 'MAeC'],
#  ['Schlanker', 'Zucchiniauflauf', 'Cottage', 'Cheese'],
#  ['Soljanka'],
#  ['Death', 'by', 'Brownie'],
#  ['Pizza',
#   'Käse',
#   'Muffins',
#   'pikantes',
#   'Gebäck',
#   'Fingerfood',
#   'Snack',
#   'Buffet',
#   'Party'],
#  ['Muffins', 'Sweet', 'Kiss'],
#  ['Blumenkohl', 'Auflauf'],
#  ['Käsekuchen', 'Boden', 'Weight', 'Watchers'],
#  ['Schneewittchen', 'Torte'],
#  ['Osterbrot'],
#  ['Pizza', 'Rosen'],
#  ['Couscous', 'Salat', 'Joghurt', 'Minze', 'Dip'],
#  ['Nudelsalat', 'sommerlich', 'mediteran'],
#  ['pikanter', 'Thunfischcreme', 'gefüllte', 'Pfannkuchen'],
#  ['Antipasti', 'Blech'],
#  ['Hackfleisch', 'Sauerkraut', 'Eintopf'],
#  ['Toffifee', 'Blätterteig'],
#  ['Quinoa', 'Pfanne', 'Breakfast', 'Quinoa'],
#  ['Grüne', 'Nudeln'],
#  ['Weihnachtsplätzchen', 'Ausstechen'],
#  ['geschüttelte', 'Party', 'Brötchen'],
#  ['Waffeln'],
#  ['Sommerpasta', 'Hähnchenbrust', 'Rucola'],
#  ['Nutella', 'Cheesecake', 'Schnitten'],
#  ['Kartoffel', 'Paprika', 'Gulasch'],
#  ['Bratäpfel', 'Cranberries', 'Vanille', 'Eis'],
#  ['Schaschlik', 'Spieße', 'Tomaten', 'Paprika', 'Sauce'],
#  ['Erdnussbutter', 'Schokoladentorte'],
#  ['Kuhfleckenwaffeln'],
#  ['Schokoladenkuchen'],
#  ['HUGO', 'Torte'],
#  ['Obazda', "für'd", 'Wiesnzeit'],
#  ['Gemüse', 'Tarte'],
#  ['Gebratene', 'Nudeln', 'Asiatisch'],
#  ['Spritzgebäck', 'Rezept', 'Mutter', 'meiner', 'Freundin'],
#  ['Geschnetzeltes', 'Gnocchi'],
#  ['Börek', 'Spinat', 'Feta', 'Füllung'],
#  ['Schokokuchen', 'flüssigem', 'Kern'],
#  ['Gemüse', 'Nudelauflauf'],
#  ['Hackfleischwunder'],
#  ['Guacamole', 'Mexikanischer', 'Avocado', 'Dip'],
#  ['italienisches', 'Brot'],
#  ['Rhabarber', 'Meringe', 'Kuchen', 'Mama'],
#  ['After', 'Eight', 'Kuchen'],
#  ['Apfel', 'Streuselkuchen'],
#  ['Schoko', 'Duo', 'Torte'],
#  ['LOW', 'CARB', 'Blumenkohl', 'Lachs'],
#  ['Lebkuchen', 'Weihnachts', 'Dessert'],
#  ['Ananas', 'Bananen', 'Torte'],
#  ['Käsekuchen', 'low', 'carb'],
#  ['Gemüselasagne'],
#  ['Nudelauflauf', 'Weightwatchers'],
#  ['BBQ', 'Burger', 'amerikanisch'],
#  ['Waffel', 'Kekse'],
#  ['waffelteig', 'stinknormaler', 'waffelteig', 'Dder'],
#  ['Schupfnudelpfanne', 'Sauerkraut'],
#  ['Puddingkuchen', 'Zitrone'],
#  ['Schneller', 'Waffelteig'],
#  ['Bunter', 'Nudelschinken', 'Auflauf'],
#  ['Oma´s', 'Rouladen'],
#  ['Pfannengericht', 'Hähnchen', 'Paprika', 'Rahmpfanne'],
#  ['Geldbeutel', 'Schoner'],
#  ['Blätterteig', 'Gebäck', 'tricolori'],
#  ['Scharfe', 'Rosenkohlpasta'],
#  ['Ofenpfannkuchen', 'süß', 'herzhaft'],
#  ['fluffigste', 'Mamorkuchen', 'überhaupt'],
#  ['Auflauf', 'Nudelauflauf', 'Hähnchenbrust'],
#  ['Gnocchi', 'Auflauf'],
#  ['Pasta', 'Schafskäse', 'Bärlauch', 'Sauce'],
#  ['Tomatenkuchen'],
#  ['Vanillekipferl', 'Mehl', 'Mandeln', 'gemahlen'],
#  ['komplette', 'Kohlsuppendiät', '7', 'Kilo', 'Woche', 'abnehmen'],
#  ['Spargel', 'Cannelloni', 'Schinkenmantel'],
#  ['Spitzkohl', 'Kartoffel', 'Hack', 'Auflauf'],
#  ['Nudel', 'Spinat', 'Auflauf', 'Käse', 'Blätterteig', 'Kruste'],
#  ['Afrikanische', 'Gemüsesuppe'],
#  ['Kartoffelsuppe'],
#  ['Schokopfannkuchen', 'Schokosauce'],
#  ['Apfel', 'Nougat', 'Kuchen', 'Streuseln'],
#  ['Taccosalat'],
#  ['Latte', 'Macchiato', 'Kuchen'],
#  ['Portugiesische', 'Puddingtörtchen', 'Pasteis', 'Nata'],
#  ['Fingerfood', 'Kartoffel', 'Räucherlachs', 'Taler'],
#  ['Fingerfood', 'Zucchini', 'Feta'],
#  ['Mousse', 'Chocolat'],
#  ['Suppe', 'Erbseneintopf'],
#  ['Salatbar', 'KRITHARAKI', 'griechische', 'Reisnudel'],
#  ['Dessert', 'Warme', 'Apfelschnitten', 'Karamell', 'Sahne'],
#  ['Gemüse', 'Nudel', 'Fleisch', 'Pfanne', 'Ofen'],
#  ['Zimt', 'Quarkbällchen'],
#  ['Wildschwein', 'Gulasch'],
#  ['Joghurt', 'Apfelmus', 'Dessert'],
#  ['Tapas', 'Oliven', 'Parmesan', 'Kugeln'],
#  ['Salate', 'Couscous', 'Salat', 'Türkische', 'kisir'],
#  ['Wrap', 'LOW', 'CARB', 'Big', 'Mac'],
#  ['Suppe', 'Feine', 'Brokkoli', 'Creme', 'Suppe'],
#  ['Ameisenkuchen'],
#  ['Champignon', 'Steinpilz', 'Suppe'],
#  ['Süße', 'Pfannkuchen'],
#  ['Bunter', 'Nudelsalat'],
#  ['chewy', 'American', 'Cookies'],
#  ['Quetschkartoffeln', 'überbacken'],
#  ['Pizza', 'Hörnchen'],
#  ['Cornflakes', 'Chicken', 'Nuggets'],
#  ['Brot', 'Brötchen', 'Fladenbrot'],
#  ['Schnell', 'Schneller', 'Apfel', 'Zimt', 'Kuchen'],
#  ['Erdbeer', 'Frischkäse', 'Torte'],
#  ['Quarktaler'],
#  ['scharfe', 'Hähnchen', 'Gemüse', 'Pfanne'],
#  ['Moussaka', 'typisch', 'Griechisch'],
#  ['Erdbeer', 'Tiramisu'],
#  ['Duplo', 'kuchen'],
#  ['Makkaroni', 'Auflauf', 'Gyros'],
#  ['Paprikaschnitzel'],
#  ['Aioli', 'geröstetem', 'Knoblauch'],
#  ['Zucchini', 'Spaghetti', 'Champignons', 'Tomaten', 'Speck'],
#  ['Double', 'Chocolate', 'Cookies', 'Echte', 'Schokoladen', 'Kekse'],
#  ['Kartoffel', 'Steinpilz', 'Cremesuppe'],
#  ['Kirsch', 'Schmand', 'Kuchen'],
#  ['Spanien', 'Empanada', 'Spanische', 'Hackfleischtarte'],
#  ['Muffin', 'Ei', '3', 'verschiedenen', 'Schinken'],
#  ['Schokoladenmuffins'],
#  ['Lachs', 'Tortillarollen'],
#  ['Hochzeitsgulasch'],
#  ['Fingerfood', 'Pizzaschiffchen', 'Bolognese'],
#  ['Pizzabrötchen'],
#  ['Erdnussbutter', 'Muffins'],
#  ['Pasta', 'Pesto', 'genovese'],
#  ['Einfacher', 'saftiger', 'Schokokuchen'],
#  ['Gefüllte', 'Käsebrötchen'],
#  ['Frühlings', 'Remoulade'],
#  ['Hähnchengeschnetzeltes', 'Brokkoli', 'Karotten'],
#  ['Kartoffel', 'Gratin', 'einfach'],
#  ['Gefülltes', 'Party', 'Brot', 'KRACHER'],
#  ['Backen', 'Einfacher', 'Fanta', 'Blechkuchen'],
#  ['Bunter', 'Fantakuchen', 'Kindergeburtstag', 'Blechkuchen', 'Muffins'],
#  ['Schneller', 'Schokokuchen'],
#  ['Hähnchen', 'Reispfanne'],
#  ['Veganer', 'Schokokuchen'],
#  ['Spargelröllchen', 'Schinkenmantel'],
#  ['Fingerfood', 'Gefüllte', 'Käse', 'Bällchen'],
#  ['Apfelkuchen', 'Mandelbelag'],
#  ['Würzfleisch', 'DDR'],
#  ['Apfelmichel',
#   'Lieblingsgericht',
#   "'Punkt",
#   "12'",
#   'Zuschauerin',
#   'Naila',
#   'Köln'],
#  ['Torten', 'Baileys', 'Torte'],
#  ['Pasta', 'Schafskäse', 'Spinat'],
#  ['Kalter', 'Hund'],
#  ['Plätzchen', 'Vanillekipferl'],
#  ['Schlanke', 'Linie', 'Eintopf', 'Diät'],
#  ['Cruffins', 'kleine', 'Frühstückchen'],
#  ['Reibekuchen', 'schnellem', 'Apfelkompott'],
#  ['Kräftige', 'Gulaschsuppe'],
#  ['Ameisenkuchen'],
#  ['Backen', 'Knuspermuffins'],
#  ['Fladenrot', 'überbacken', 'Elsässer'],
#  ['Abendbrot', 'kohlenhydratreduziertes', 'Brot'],
#  ['Wirsing', 'Hacktorte'],
#  ['Blätterteigtaschen',
#   'gefüllt',
#   'Spinat',
#   'Feta',
#   'Pinien',
#   'kernen',
#   'Feldsalat'],
#  ['Erdbeertorte'],
#  ['Falscher', 'Hase'],
#  ['Brathendl', 'Hendl', 'Hähnchen'],
#  ['Chili', 'Carne'],
#  ['Kuchen', 'backen', 'Himbeertorte'],
#  ['Gnocchi', 'Salat'],
#  ['Feurige', 'Gulasch', 'Kartoffelsuppe'],
#  ['Geschichtetes', 'Fleisch'],
#  ['Nudelsalat', 'sommerlich', 'bunt'],
#  ['belgische', 'Fritten', 'Belgische', 'Pommes', 'frites'],
#  ['Bandnudeln', 'Frühlingszwiebeln', 'frischen', 'Chamignons'],
#  ['Mazedonisches', 'Geheimnis'],
#  ['Feta', 'Tomaten', 'Auflauf'],
#  ['Johannisbeer', 'Baiser', 'Kuchen'],
#  ['Lime', 'Cheesecake'],
#  ['Schnitzelpizza'],
#  ['jugoslavija', 'cevapcici'],
#  ['Spaghetti', 'Carbonara', 'Deutsche'],
#  ['LowCarb', 'Coleslaw'],
#  ['Pizzamuffins'],
#  ['Party', 'Hackfleisch', 'Käse', 'Semmeln'],
#  ['Afrikanischer', 'Eintopf', 'angolan'],
#  ['Herzhafte', 'Kartoffel', 'Spieße'],
#  ['APPETITHÄPPCHEN', 'GEFÜLLTE', 'BAGUETTES'],
#  ['Apfel', 'Kiwi', 'Smoothie'],
#  ['Quiche', 'Ziegenkäse', 'Tomaten'],
#  ['Hühnerfrikassee'],
#  ['Easy', 'Blätterteig', 'Frühstücksring'],
#  ['Pfannkuchen'],
#  ['Camembert', 'Blätterteig'],
#  ['Thai', 'Curry'],
#  ['Kronenkuchen', 'Quark', 'Streuselkuchen'],
#  ['Spaghetti', 'Carbonara', 'Italienische'],
#  ['Weißer', 'Hund', 'Kalter', 'Hund', 'Himbeeren'],
#  ['Avocado', 'Dip', 'ähnlich', 'Guacamole'],
#  ['Schicht', 'Torte', 'weißer', 'Schokolade', 'Eierlikör'],
#  ['Käse', 'Scharfe', 'Käsebällchen', 'fruchtiger', 'Sauce'],
#  ['Pfannengerichte', 'Brokkoli', 'Curry', 'Pfanne'],
#  ['Brokkoli', 'Kartoffel', 'Auflauf'],
#  ['Bananen', 'Schoko', 'Sahne', 'Torte'],
#  ['Chili', 'carne'],
#  ['Cevapcici', 'Djuvec', 'Reis'],
#  ['Überbackener', 'Heißer', 'Max'],
#  ['Einfach', 'Waffeln'],
#  ['Pizza'],
#  ['Mozzarella', 'gefüllte', 'Kartoffel', 'Kräuter', 'Taler'],
#  ['Kartoffel', 'Rösti', 'Champignons', 'Käse', 'überbacken'],
#  ['Meine', 'ultimative', 'Lasagne'],
#  ['Fingerfood', 'Tomaten', 'Quadrate'],
#  ['Bauern', 'Frühstück', 'uns', 'Mittag', 'Essen'],
#  ['Gratinierte',
#   'Putenschnitzel',
#   'Caprese',
#   'Pesto',
#   'Spaghetti',
#   'warmen',
#   'Tomatensalat'],
#  ['Räuberfleisch'],
#  ['Mini', 'Schokoladen', 'Tarte', 'Himbeeren'],
#  ['Oreo', 'Kekse', 'deluxe'],
#  ['Sahniges', 'Schweinefilet', 'Pfeffersoße'],
#  ['Fluffige', 'Waffeln'],
#  ['Cheesecake', 'Brownies'],
#  ['Sonntagswaffeln'],
#  ['Spaghetti', 'Carbonara'],
#  ['Linzer', 'Spritzgebäck'],
#  ['Gyrossuppe'],
#  ['Salate', 'Griechischer', 'Bauernsalat'],
#  ['Aller', 'allerbeste', 'Chocolate', 'Chip', 'Cookies'],
#  ['Freundliche', 'Blicke'],
#  ['Torten', 'Espressocreme', 'Torte'],
#  ['Buntes', 'Reisfleisch'],
#  ['Spaghetti', 'aglio', 'olio'],
#  ['Schokokuss', 'Creme', 'Pfirsich'],
#  ['Zigeuner', 'Soße'],
#  ['Bärlauch', 'Quiche'],
#  ['Spanische', 'Reispfanne', 'Hühnchen'],
#  ['Churros', 'heisser', 'Schokolade'],
#  ['Joghurt', 'Brot'],
#  ['Orientalische', 'Hackbällchen', 'Spitzpaprikarahm'],
#  ['Nudelsalat', 'klassisch'],
#  ['Oreo', 'Cupcakes', '12', 'Stück'],
#  ['Käsekuchen', 'anders'],
#  ['Italienischer', 'Nudelsalat', 'Giulietta'],
#  ['Tiramisu'],
#  ['Überbackene', 'Paprika', 'griechischer'],
#  ['Rehkeule', 'butterzart', 'Niedrigtemperatur'],
#  ['Vegetarische', 'Küche', 'Scharfe', 'Linsen', 'Möhren', 'Bratlinge'],
#  ['Backofenschnitzel', '24', 'Stunden'],
#  ['Vegetarisch', 'gefüllte', 'Zucchini'],
#  ['Limonade'],
#  ['Überbackene', 'Wiener', 'Würstchen'],
#  ['Gurkensalat'],
#  ['Ei',
#   'Ei',
#   'Ei',
#   'V',
#   'sondern',
#   'selbstgemachter',
#   'Eierlikör',
#   'Bilder',
#   'ON'],
#  ['Kohlrabi', 'Kartoffel', 'Gratin'],
#  ['Torten',
#   'Schokoladen',
#   'Mascarpone',
#   'Torte',
#   'Torte',
#   'Foto',
#   'eingestellt'],
#  ['Creme', 'Brulee'],
#  ['Schoko', 'Karamell', 'Erdnuss', 'Happen'],
#  ['Frühstücks', 'Brötchen'],
#  ['Beeren', 'Smoothie'],
#  ['Tortelloni', 'Auflauf'],
#  ['Dessert', 'Erdbeer', 'Joghurt', 'Quark'],
#  ['Kartoffelsuppe', 'Schinken'],
#  ['Überraschungseier', 'Dessert', 'Ostern', 'Kinder'],
#  ['Putengeschnetzeltes', 'Wok'],
#  ['Ital', 'Fingerfood'],
#  ['Garnelen', 'Päckchen'],
#  ['schnellste', 'Weißbrot', 'Welt'],
#  ['Apfelkuchen', 'Schmand', 'Blech'],
#  ['Baklava', 'Haselnuss', 'genaue', 'Beschreibung', 'Bild'],
#  ['Farmerkartoffeln'],
#  ['Rhabarber', 'Streuselkuchen'],
#  ['kleine', 'Quarkpfannkuchen', 'süß', 'pikant'],
#  ['Kekse', 'Plätzchen', 'Marzipankugeln'],
#  ['Hawaii', 'Schnitzel'],
#  ['Zwei', 'Zutaten', 'Pfannkuchen'],
#  ['Gulaschsüppchen'],
#  ['Zwiebelkuchen'],
#  ['Spaghetti', 'Carbonara'],
#  ['Lebkuchen', 'Kirsch', 'Torte'],
#  ['Selbstgemachte', 'Pommes', 'Ofen'],
#  ['Ajvar', 'selbstgemacht'],
#  ['Ess', 'mich', 'dumm', 'dran', 'Suppe'],
#  ['Fruchtzwergetorte'],
#  ['Pizzabrötchen'],
#  ['Erdbeerkuchen'],
#  ['Spaghetti', 'Carbonara'],
#  ['Paprika', 'Sahne', 'Hähnchen', 'Tüte'],
#  ['Plätzchen'],
#  ['Gyros', 'überbacken', 'Metaxasoße'],
#  ['Nudelsalat', 'Caprese'],
#  ['Tomatensuppe'],
#  ['Spargel', 'italienische', 'Tomaten', 'Mozzarella', 'überbacken'],
#  ['Schokokuchen'],
#  ['Spaghetti', 'Garnelen', 'Sahnesauce'],
#  ["Gabi's", 'bunt', 'gemixter', 'Blumenkohlauflauf'],
#  ['Marzipantorte', 'Eierlikör'],
#  ['Pfannkuchen'],
#  ['Milchschnitten', 'Muffins'],
#  ['Weihnachtsplätzchen', 'Lebkuchen', 'Männchen'],
#  ['Pizzasuppe'],
#  ['Cake', 'Pops'],
#  ['Makkaroni', 'Käse', 'Donuts'],
#  ['Club', 'Sandwich'],
#  ['Apfelkuchen', 'Oma'],
#  ['Papageienkuchen', 'Fasching', 'Kindergeburtstag'],
#  ['Käse', 'Zwiebel', 'Schinken', 'Quiche'],
#  ['griechischer', 'hirtensalat'],
#  ['Schneckenkuchen'],
#  ['Klassischer', 'Kartoffelgratin'],
#  ['Apfelkuchen', 'Topf'],
#  ['Barbecuesauce', 'Martin'],
#  ['LINGUINE',
#   'AI',
#   'SCAMPI',
#   'FIAMMEGGIATI',
#   'Pasta',
#   'flambierten',
#   'Scampis'],
#  ['Zitronen', 'Hühnchen'],
#  ['Bounty', 'Mogel', 'Kuchen'],
#  ['Fisch', 'Hähnchen', 'Nuggets', 'Kinder', 'Gericht'],
#  ['Cevapcici', 'Djuvec', 'Reis', 'scharfen', 'roten', 'Zwiebeln'],
#  ['All', 'American', 'Clubsandwich'],
#  ['Mediterraner', 'Nudelsalat'],
#  ['Weihnachtsdessert'],
#  ['Basilikum', 'Tomatensuppe', 'Mozzarella'],
#  ['Weihnachtsplätzchen', 'Non', 'Plus', 'Ultra'],
#  ['Fingerfood', 'Schinken', 'Kugeln'],
#  ['Suppe', 'Können', 'nochmal', 'machen?'],
#  ['Kuchen', 'Tüten'],
#  ['Blueberry', 'Cupcakes'],
#  ['APPETITHÄPPCHEN', 'LACHSRÖLLCHEN'],
#  ['Curry', 'Nudeln'],
#  ['Fingerfood', 'Käse', 'Schinken', 'Hefeteilchen', 'Enroladinhos'],
#  ['Milchschnitten', 'Torte'],
#  ['Switchel', 'Grundrezept'],
#  ['Gebratener', 'Lachs', 'Bärlauch', 'Risotto'],
#  ['Zitronenhühnchen', 'Gemüse', 'Folie', 'gegart'],
#  ['Spaghetti', 'Carbonara'],
#  ['Pizza'],
#  ['Nudeleintopf', 'Hackbällchen'],
#  ['Döner', 'selbstgemacht'],
#  ['Erdbeer', 'Waldmeistertorte'],
#  ['Mini', 'Karamell', 'Apfel', 'Tartes'],
#  ['Putenfilet', 'gefüllt'],
#  ['Senfeier', 'Kapern', 'Kartoffelpüree'],
#  ['Überbackenes', 'Schnitzel', 'TOMATE', 'MOZZARELLA'],
#  ['Focaccia'],
#  ['Hackbällchen', 'fruchtiger', 'Tomatensauce'],
#  ['Kichererbsen', 'Eintopf'],
#  ['Pizza', 'Salami', 'Brötchen'],
#  ['Russischer', 'Zupfkuchen'],
#  ['Backwaren', 'Apfel', 'Streusel', 'Kuchen'],
#  ['Wiener', 'Schnitzel', 'Kalb', 'Pellkartoffelsalat'],
#  ['Kartoffel', 'Kohlrabi', 'Gratin'],
#  ['Schichtsalat'],
#  ['Brownies', 'Schokoladig'],
#  ['Apfelkrapfen'],
#  ['Donauwelle'],
#  ['Pasta', 'Fleischbällchen'],
#  ['Dutch', 'Apple', 'Caramel', 'Streusel', 'Cheesecake'],
#  ['Fleisch', 'Rotwein', 'Schmorbraten'],
#  ['Stracciatella', 'Erdbeer', 'Schnitten'],
#  ['Linsen', 'Eintopf', 'Omas', 'Rezept'],
#  ['American', 'Pancakes'],
#  ['Pasta', "all'", 'Arrabiata'],
#  ['Apfelkuchen', 'Vanillebuttercreme'],
#  ['Banana', 'Pancakes'],
#  ['Erdbeer', 'Tiramisu'],
#  ['Zauberkuchen'],
#  ['Bärlauchpesto', 'Walnüssen'],
#  ['Bunte', 'Garnelen', 'Spaghetti', 'Pfanne', 'Blattspinat'],
#  ['Bisquitboden',
#   'hoch',
#   'Biskuit',
#   'Bisquit',
#   'Tortenboden',
#   'hell',
#   'dunkel',
#   'Bäcker'],
#  ['Pflaumenmus'],
#  ['Tassenkuchen', 'Mikrowelle'],
#  ['Vier', 'Minuten', 'Hühnerfrikassee'],
#  ['Einfache', 'Kürbissuppe'],
#  ['Kirsch', 'Zwerg'],
#  ['Stockbrot'],
#  ['Smoothies', 'Gelb', 'Pink'],
#  ['Pasta', 'luxe', 'Dillschaum'],
#  ['Amerikaner', '20', 'Minuten', 'fertig'],
#  ['Holunderblütensirup'],
#  ['Feldsalat', 'warmen', 'Kartoffeldressing', 'Speckwürfeln'],
#  ['Eiersalat'],
#  ['Grillen', 'BBQ', 'Spareribs', 'Southern', 'Marinade'],
#  ['Cremiges', 'Schokoladen', 'Joghurt', 'Eis'],
#  ['Paprika', 'Feta', 'Knoblauch', 'Dip'],
#  ['Skandinavische', 'Kartoffelsuppe'],
#  ['Zucchinipasta'],
#  ['Apfelsinenstäbchen'],
#  ['Bohnen', 'Eintopf', 'Hackklößchen'],
#  ['Thailändischer', 'Glasnudelsalat'],
#  ['Mini', 'Intermezzi'],
#  ['Kuchen', 'beste', 'Waffelrezept', 'Hälfte'],
#  ['Amerikaner'],
#  ['Pasta', 'Zucchini', 'Käsesauce'],
#  ['Tassenknödel'],
#  ['Grundteig', 'Flammkuchen'],
#  ['Blumenkohl', 'Kartoffel', 'Auflauf', 'Vegetarisch'],
#  ['Grillen', 'BBQ', 'Grillmarinade'],
#  ['schicke', 'Erdbeer', 'Frischkäse', 'Torte'],
#  ['Gemüse', 'cremiger', 'Erdnuss', 'Sauce'],
#  ['Reis', 'Auflauf', 'Hähnchen'],
#  ['Schoko', 'Orangen', 'Kuchen'],
#  ['Mutters', 'Käsekuchen'],
#  ['Oma', 'Friede`s', 'Sandkuchen', 'Rzpt', '1920'],
#  ['Sauce', 'BOLOGNESE'],
#  ['Wiener', 'Schnitzel', 'Kartoffelgratin'],
#  ['Cloud', 'Eggs', 'Wolken', 'Eier', 'Frühstück'],
#  ['Kaiserschmarrn'],
#  ['Lasagne'],
#  ['Wiesn', 'Burger'],
#  ['Fingerfood', 'Salatröllchen'],
#  ['Zucchini', 'Spaghetti', 'Garnelen'],
#  ['Weihnachtsmarkt', 'Klassiker', 'selbermachen'],
#  ['Americans', 'Best', 'Burger'],
#  ['Rotes', 'Thai', 'Curry'],
#  ['Königsberger', 'Klopse'],
#  ['Clubsandwishes', 'frisch', 'zubereitet', 'echt', 'Lecker'],
#  ['Oreo', 'Kuchen', "'Giant", 'Oreo', "Cake'"],
#  ['Grundrezept', 'Nudelteig', 'Ei'],
#  ['Leichte', 'Donauwelle'],
#  ['After', 'Eight', 'Torte'],
#  ['Waffeln'],
#  ['Zwiebelkuchen', 'Blech'],
#  ['Sisserl’s', 'Champignon', 'Auflauf'],
#  ['Salatdressing', 'Sylter'],
#  ['Knoblauch', 'Brötchen'],
#  ['Pfannkuchen', 'Milch'],
#  ['Spaghettisalat', 'Pute'],
#  ['Leicht', 'verdaulicher', 'Makkaroni', 'Schinkenauflauf'],
#  ['Gnocchi', 'Tomaten', 'Kapernsoße'],
#  ['Zwei', 'Zutaten', 'Kekse'],
#  ['Nutella', 'Eis'],
#  ['Lasagne', 'Lieblingsgericht', 'Familie', 'Moll'],
#  ['Zwiebel', 'Schinken', 'Brot'],
#  ['Cremige', 'Tomaten', 'Hack', 'Suppe'],
#  ['Gefüllte', 'Champignons', '3', 'kreative', 'Varianten'],
#  ['Kokosmakronen'],
#  ['Himbeer', 'Schicht', 'Dessert'],
#  ['BBQ', 'Soße'],
#  ['Medaillons', 'gratiniert'],
#  ['Easy', 'Mini', 'Frittatas'],
#  ['Weihnachtsdessert', 'Apfel', 'Schoko', 'Karamell', 'Schichtcreme'],
#  ['Mandarinen', 'Trifle'],
#  ['Mohntorte'],
#  ['Entenbrust', 'sanft', 'gegart'],
#  ['Plätzchen', 'Engelsaugen'],
#  ['Dessert', 'Obstsalat', 'trifft', 'Schokokuss'],
#  ['Basilikum',
#   'Putenschnitzel',
#   'Reis',
#   'gefüllt',
#   'Parmesan',
#   'Ei',
#   'gebraten'],
#  ['Amerikanischer', 'Käsekuchen'],
#  ['Bami', 'Goreng', 'ORIGINAL'],
#  ['Muffins', 'Schnelle', 'saftige', 'Schokomuffins'],
#  ['Käsefüße'],
#  ['Zwei', 'Zutaten', 'Brownies'],
#  ['Geflügel', 'Gemüse', 'Auflauf'],
#  ['Eierlikör', 'selber'],
#  ['Ajvar', 'Hähnchenspiesse'],
#  ['Curry', 'Hähnchen', 'Geschnetzeltes', 'tolles', 'Partyrezept'],
#  ['Fingerfood', 'Schinkenpäckchen'],
#  ['Marshmallow', 'Gratin', 'Schokolade'],
#  ['Pasta', 'sugo', 'salsiccia'],
#  ['Apfelkuchen', 'Pudding'],
#  ['BROT', 'Focaccia'],
#  ['Gyrosauflauf'],
#  ['American', 'Strawberry', 'Cheesecake'],
#  ['Zimtschnecken', 'Cinnamon', 'Rolls'],
#  ['Pfannkuchen', 'Lasagne'],
#  ['quark', 'rührkuchen'],
#  ['Italienische', 'Nudelsalate', 'Gnocchi', 'Salat', 'Tortellini', 'Salat'],
#  ['Quinoa', 'Pfanne', 'Gemüse', 'Erdnusssauce'],
#  ['Erdbeertiramisu'],
#  ['Ketchup', 'american'],
#  ['Nudeln', 'Hähnchenbrustfilet', 'Gorgonzola', 'Sauce'],
#  ['Bandnudeln', 'Lachs'],
#  ['Sommer', 'Suppe'],
#  ['Buttermilchkuchen'],
#  ['Gebackener', 'Brokkoli'],
#  ['Blumenkohl', 'Pasta', 'aglio', 'olio'],
#  ['Schoko', 'Nuss', 'Kuchen'],
#  ['Schnitzel', 'Pilz', 'Rahm', 'Sauce'],
#  ['Bananen', 'Himbeer', 'Smoothie', 'löffeln'],
#  ['Brot', 'Subway', 'Baguette'],
#  ['Marmor', 'Muffins'],
#  ['Griechische', 'Hackfleisch', 'Pfanne'],
#  ['Geflügel', 'Schlemmer', 'Hähnchenschnitzel'],
#  ['Zauberkuchen', 'Daniela', 'Coellen', 'Köln'],
#  ['OREO', 'Torte'],
#  ['Pfannen', 'Pizza', 'vegetarische', 'Variante'],
#  ['Brokkoli', 'Quiche'],
#  ['Schoko', 'Bananen', 'Torte'],
#  ['Gözleme'],
#  ['Tschebureki', 'Rezept'],
#  ['Riesen', 'Yogurette', 'Torte', 'Backen'],
#  ['Bayr', 'Schmankerl', 'K', 'K', 'Braten'],
#  ['Fürst', 'Pückler', 'Kuchen'],
#  ['Alpenmakrönli'],
#  ['Spargel', 'Quiche'],
#  ['Fleisch', 'Rahmlendchen'],
#  ['Feurige', 'Currysuppe', 'Garnelen', 'Kartoffelchips'],
#  ['Party', 'Pizza', 'Nudeltopf'],
#  ['Kaiserschmarrn'],
#  ['Nudeln', 'Putenstreifen', 'Tomatensoße'],
#  ['Falafel'],
#  ['Zitronenschnitten'],
#  ['Zwiebelkuchen', 'Teig', 'Mehl'],
#  ['Kikis', 'Biskuit', 'Bienenstich', 'light'],
#  ['Big', 'Mac', 'Salat'],
#  ['Susi', 'Strolch', 'Pasta'],
#  ['Kretapfanne'],
#  ['Couscous', 'Bratlinge', 'Kräuter', 'Dip'],
#  ['Fladenbrotpizza', 'Hackfleisch'],
#  ['Apfelkuchen', 'Guss', 'Weight', 'Watchers'],
#  ['Bayerischer', 'rheinischer', 'Kartoffelsalat'],
#  ['Avocado', 'Grill'],
#  ['Minikuchen', 'Waffelbecher'],
#  ['Panna', 'Cotta'],
#  ['Faschings', 'Kräppele>>'],
#  ['Kürbis', 'Quiche'],
#  ['Aioli', 'Tortellinisalat'],
#  ['Lasagne', 'bolognese', 'classico'],
#  ['Schnelles', 'Toast', 'Brötchen', 'low', 'carb'],
#  ['Apfelkuchen'],
#  ['Afrikanischer', 'Früchte', 'Amarula', 'Traum', 'Kokossahne'],
#  ['Bärlauchbutter'],
#  ['Kuchen', 'Nutella', 'Kuchen'],
#  ['Herzhafte', 'Mozzarella', 'Waffeln'],
#  ['Brot', 'Schnelles', 'Dinkelbrot'],
#  ['Zucchinipuffer', 'Schmand', 'Dip'],
#  ['Nudelsalat'],
#  ['Sandwich',
#   'glasierter',
#   'Hühnerbrust',
#   'Ziegenkäse',
#   'gegrillter',
#   'Paprika'],
#  ['Steinpilze', 'heute', 'rahmiger', 'Soße'],
#  ['Kartoffelgratin'],
#  ['Mohn', 'Käsekuchen'],
#  ['KitKat', 'Kuchen'],
#  ['Chicken', 'Curry', 'Hähnchenbrustfilet', 'Kokossoße'],
#  ['Himbeer', 'Baiser', 'Nachtisch'],
#  ['coole', 'thunfischbaguettes'],
#  ['Kuchen', 'Stracciatella', 'Cheese', 'Cake', 'Trauben'],
#  ['fettarmer', 'Kartoffelsalat', 'Weight', 'Watcher', 'geeignet'],
#  ['Bananen', 'Kuchen'],
#  ['Gebratenes', 'Hühnerfleisch', 'Gemüse', 'Hoi', 'Sin', 'Sauce', 'scharf'],
#  ['Knusper', 'Blumenkohl', 'Senfeiern'],
#  ['Kartoffel', 'Bolognese', 'Auflauf'],
#  ['Lachs', 'Gemüse', 'Nudeln'],
#  ['Vollkornbrot'],
#  ['Party', 'Currywurst', 'Topf'],
#  ['Tomaten', 'Zucchini', 'Quiche'],
#  ['Leichte', 'Spargel', 'Soße'],
#  ['Schnelle', 'Fladen', 'Pfanne', 'Hefe'],
#  ['Bärlauch', 'Spätzle', 'Parmesan', 'Sauce'],
#  ['Baileys', 'Kugeln'],
#  ['Hähnchenbrust', 'gratiniert', 'Gemüse', 'Pilzbett', 'Feta'],
#  ['Hackfleischpizza'],
#  ['Paella'],
#  ['Spargel', 'Schiffchen', 'Schmortomaten'],
#  ['Versunkener', 'Apfelkuchen', 'Eierlikör'],
#  ['Spinnennest'],
#  ['Wraps', 'Lachs', 'Käse', 'Schinken'],
#  ['Joghurttorte', 'Sommertraum'],
#  ['Makkaroni', 'Auflauf'],
#  ['Fadennudel', 'Bällchen'],
#  ['Brot', 'CIBATTA', 'Walnüssen', 'eingelegten', 'Tomaten'],
#  ['Chili', 'Carne'],
#  ['Zupfbrot', 'Kräuterbutter'],
#  ['Gemüse', 'Hackfleisch', 'Feta', 'Auflauf'],
#  ['Blumenkohl', 'Omelett'],
#  ['Pancakes'],
#  ['Putenröllchen', 'gefüllt', 'Basilikum', 'Weißweinsauce'],
#  ['Waffeleisen', 'Pizza'],
#  ['Rotes', 'Hähnchencurry'],
#  ["Anabel's", 'fixe', 'Hackfleischbrötchen'],
#  ['Erbsen', 'Gemüse', 'Eintopf'],
#  ['Apfelkuchen', 'WW'],
#  ['Flammkuchen', 'Grill'],
#  ['Schoko', 'Kirsch', 'Tiramisu'],
#  ['Pasta', 'Spaghetti', 'Krebsschwanz', 'Zuckerschoten', 'Ragout'],
#  ['Weißkohl', 'Rouladen', 'Muttern'],
#  ['Überbackener', 'Blumenkohl'],
#  ['Pikante', 'Kuchen', 'Elsässer', 'Flammkuchen'],
#  ['Bayrische', 'Kartoffelsuppe'],
#  ['Raffaello'],
#  ['Spargel', 'Bärlauch', 'Mayonnaise'],
#  ['Zwetschgenkuchen'],
#  ['Mousse', 'Chocolat'],
#  ['Bananen',
#   'Kokos',
#   'Hühnchen',
#   'Curry',
#   'exotisch',
#   'fruchtig',
#   'karibisch'],
#  ['Eier', 'Senfsoße', 'genau', 'hat', 'Oma', 'schon', 'gekocht'],
#  ['Berliner', 'Krapfen'],
#  ['Tapas', 'Fingerfood', 'Parmesansterne'],
#  ['Kikis', 'Joghurt', 'Rührkuchen', 'light'],
#  ['Hähnchenbrustfilet', 'indisch'],
#  ['Marmorkuchen'],
#  ['Blitzrouladen'],
#  ['Waffeln', 'frischen', 'Erdbeeren', 'Sahne'],
#  ['Kokos', 'Konfekt', 'Raffaello'],
#  ['Pasta', 'Brokkoli', 'Käsesauce'],
#  ['AfterEight', 'Schicht', 'Dessert'],
#  ['Überbackene', 'Zucchini', 'Gemüse', 'Feta', 'Füllung'],
#  ['Schwarzwälder', 'Kirschtörtchen'],
#  ['Asti', 'Erdbeer', 'Torte'],
#  ['Kartoffel', 'RÖSTI', 'schnell', 'selbstgemacht'],
#  ['Spinat', 'Lachs', 'Rolle'],
#  ['Klassischer', 'Thunfischsalat'],
#  ['Amerikaner'],
#  ['Nudeln', 'Asia', 'Bolognese'],
#  ['Mohn', 'Pudding', 'Kuchen'],
#  ['Negerkusstorte', 'Dickmann', 'Torte'],
#  ['Nudel', 'Torte', 'Blattspinat'],
#  ['Pflaumenkuchen'],
#  ['Balsamicohähnchen', 'Bandnudeln'],
#  ['Brot', 'gesundes', 'Ruck', 'Zuck', 'Brot'],
#  ['Balearischer', 'Kartoffelsalat'],
#  ['Hackbraten', 'anders'],
#  ['Apfel', 'Mascarpone', 'Kuchen'],
#  ['Mandarinenkuchen'],
#  ['Spaghetti', 'Orangen', 'Garnelen'],
#  ['Gyros', 'Metaxa', 'Sauce'],
#  ['Steinpilz', 'Carbonara', 'Bergkäse'],
#  ['Meeresfrüchte', 'Pfanne'],
#  ['Rotkäppchen', 'Torte'],
#  ['Ferrero', 'Rocher', 'Torte'],
#  ['Kürbis', 'Ingwer', 'Kokos', 'Suppe'],
#  ['Fruchtiger', 'Sommersalat'],
#  ['Gebackene', 'Mozzarellaschnitten', 'Salbei', 'Schmortomaten'],
#  ['Cannelloni', 'Spinat', 'Ricottacreme', 'Lachswürfeln'],
#  ['Camembert',
#   'Preiselbeer',
#   'Blätterteigschnecken',
#   'Fingerfood',
#   'Fastfood',
#   'pikanter',
#   'Snack'],
#  ['Paprika', 'gefüllt', 'Rinderhack', 'Reis', 'Füllung', 'Tomatenreis'],
#  ['Süßkartoffel', 'Pommes'],
#  ['Schokoladen', 'Cupcakes', 'Schoko', 'Topping'],
#  ['Zwiebelkuchen'],
#  ['Elsässer', 'Flammkuchen'],
#  ['Puten', 'Curry', 'Pfirsichen'],
#  ['Spaghetti', 'Carbonara', 'originale'],
#  ['Pulled',
#   'Pork',
#   'Grill',
#   'geräuchert',
#   'selbstgemachten',
#   'Semmeln',
#   'Krautsalat',
#   'Barbecuesoße'],
#  ['Banane', 'Nußmantel', 'Grill'],
#  ['Nusskuchen', 'Schokostückchen'],
#  ['Blätterteigpizza'],
#  ['raffaello', 'pralinen'],
#  ['Fantakuchen', 'Grundrezept', '1', 'Blech', '24', 'Muffins'],
#  ['Plätzchen', 'Besitos', 'Küsschen'],
#  ['Afrikanischer', 'Erdnusstopf'],
#  ['Zimt', 'Waffel', 'Schnitten', 'Knusperfüllung'],
#  ['Hackfleisch', 'Schmand', 'Torte'],
#  ['Blaubeer', 'Muffins'],
#  ['Apfel', 'Tiramisu'],
#  ['DDR', 'Brötchen'],
#  ['Fingerfood', 'Flammkuchen'],
#  ['Bienenstich', 'Rührteig'],
#  ['Regenbogenkuchen'],
#  ['Pasta', 'Steak', 'Sauce'],
#  ['Party', 'Saftige', 'Pizza', 'Semmeln'],
#  ['Friesentorte'],
#  ['Plätzchen', 'Schwarze', 'Schlingel'],
#  ['Ananas', 'Carpaccio', 'Bounty', 'Creme'],
#  ['Pfannengerichte', 'Gemüse', 'reispfanne'],
#  ['Nudelsalat'],
#  ['Garnelen', 'scharfer', 'Johannisbeersoße', 'Asianudeln'],
#  ['Schneller', 'Käsekuchen'],
#  ['Hähnchenbrustfilet', 'Chilikäse', 'Champignonsahnesauce'],
#  ['Joghurt', 'Beeren', 'Nüssen'],
#  ['Pastizio', 'Auf'],
#  ['Alo', 'Gobi'],
#  ['Chinakohl', 'Pfanne'],
#  ['Amaretto', 'Apfelkuchen'],
#  ['6', 'Euro', 'Auflauf'],
#  ['Mars', 'Torte'],
#  ['Quarkbällchen'],
#  ['Flammkuchen', 'Elsässer'],
#  ['Gemüsesuppe', 'Grießklößchen'],
#  ['Hühnerfrikasee'],
#  ['Gefüllte', 'Hörnchen'],
#  ['Marshmallow', 'Schoko', 'Eclairs'],
#  ['Kuchen', 'Pflaumenkuchen'],
#  ['Feuriges', 'Beef', 'Sandwich'],
#  ['Spritzgebäck'],
#  ['Italienische', 'Tomatensauce'],
#  ['Wirsing', 'Kohlrouladen', 'pikant'],
#  ['Kartoffel', 'Lauch', 'Auflauf', 'Ricotta'],
#  ['Amsterdamer', 'Filettopf'],
#  ['★', 'Kartoffel', 'Zucchini', 'Gulasch', 'Mettwürstchen', '★'],
#  ['Fränkisches', 'Schäufele', 'Dunkelbiersoße'],
#  ['Böhmische', 'Knödel'],
#  ['Käse', 'Schinken', 'Muffins'],
#  ['Amaretto', 'Erdbeer', 'Torte'],
#  ['Pizzaschnecken'],
#  ['Lachsfilet', 'asiatischer', 'Paprika', 'Tomaten', 'Sauce', 'Reis'],
#  ['Cheesecake', 'Törtchen', 'Schichtdessert'],
#  ['Hokkaido', 'Kürbiscremesuppe'],
#  ['Spaghetti', 'Pfifferlingen', 'Schinken'],
#  ['Party', 'Blätterteig', 'Käse', 'Snack'],
#  ['Fleisch', 'Schweinelendchen', '1', 'Kochbar', 'Geburtstag'],
#  ['Schokoladen', 'Tarte'],
#  ['Hack', 'Baguettes', 'provenzalisch'],
#  ['Mascarponecreme'],
#  ['Nussecken', 'Plätzchen'],
#  ['After', 'Eight', 'Creme'],
#  ['Klassischer', 'Nudelsalat'],
#  ['saftiger', 'Kirschkuchen'],
#  ['Backofentomaten', 'Feta'],
#  ['Nudelsalat'],
#  ['Spaghetti', 'Käse', 'Schinken', 'Sauce'],
#  ['Rouladen', 'selbstgemachtem', 'Rotkohl'],
#  ['Enchiladas'],
#  ['Lahmacun', 'Türkische', 'Pizza'],
#  ['Club', 'Sandwich'],
#  ['Bifteki', 'Suflaki', 'griechischen', 'Reisnudeln', 'Ofenkartoffeln'],
#  ['einfache', 'Hack', 'Chinakohl', 'Pfanne'],
#  ['Schichtsalat'],
#  ['Stacciatella', 'Kirsch', 'Kuchen'],
#  ['Nacho', 'Chili', 'Cheese', 'Dip'],
#  ['Himbeer', 'Streusel', 'Torte'],
#  ['PLÄTZCHEN', 'Marzipan', 'Sternchen'],
#  ['Kohlrabischnitzel', 'Schnittlauchquark'],
#  ['Gemüse', 'Couscous', 'Paprika'],
#  ['Fladenbrot'],
#  ['Gemüseauflauf'],
#  ['Mini', 'Zitronen', 'Blumen', 'Kuchen'],
#  ['Wirsing', 'Quiche'],
#  ['Zitronen', 'Biskuitrolle'],
#  ['Knackig', 'leichte', 'Pommes', 'Frites'],
#  ['Himbeer', 'Frischkäse', 'Torte'],
#  ['Philadelphia', 'Torte'],
#  ['Auflauf', 'Putenschnitzel', 'griechischer'],
#  ['einzig', 'echte', 'orginal', 'Tiramisu'],
#  ['Kasseler', 'Sauerkraut', 'Kartoffelpüree'],
#  ['Holunderbeerlikör'],
#  ['Rhabarber', 'Käse', 'Kuchen', 'Blech'],
#  ['Daim', 'Torte'],
#  ['Raffinierte', 'Mini', 'Party', 'Pizzen'],
#  ['Beilage', 'Baked', 'Potatoes'],
#  ['Kuchen', 'Eierlikör'],
#  ['Bunter', 'Salat', 'Hähnchenstreifen'],
#  ['Kürbis', 'Apfel', 'Suppe'],
#  ['Lachsrolle'],
#  ['Apfel', 'Zimt', 'Küchlein'],
#  ['Zucchini', 'Tomaten', 'Suppe', 'Weight', 'Watchers'],
#  ['Quark', 'Cannelloni'],
#  ['New', 'York', 'Cheesecake'],
#  ['Tortellini', 'Auflauf'],
#  ['Supa', 'Toptscheta', 'bulgarische', 'Suppe', 'Hackfleisch', 'Bällchen'],
#  ['Fruchtiger', 'Blechkuchen'],
#  ['Veganer', 'Limetten', 'Minz', 'Cheesecake'],
#  ['Orangenknöpfchen', 'zergehen', 'Zunge'],
#  ['Erdbeer', 'Schokoknusper', 'Torte'],
#  ['Apfeltaschen'],
#  ['Herzhafte', 'Pfannkuchen', 'Gemüse'],
#  ['Erdbeer', 'QuarkCreme', 'Torte'],
#  ['Plätzchen', 'Mohn', 'Kekse'],
#  ['Baklava'],
#  ['Meißner', 'Quarktorte'],
#  ['sauerkirschstreusel'],
#  ['Broccoli', 'Nudel', 'Auflauf', 'Weight', 'Watchers'],
#  ['Entenbraten'],
#  ['Lauch', 'Tatar', 'Suppe'],
#  ['Einfache', 'Butterplätzchen'],
#  ['Backen', 'Erdbeer', 'Pfirsich', 'Kuppeltorte'],
#  ['1Pfannengericht', 'Steyrer', 'Eisenherrnpfandl'],
#  ['Sahne', 'Quark', 'Mousse'],
#  ['Elsässer', 'Flammkuchen'],
#  ['Schnellster', 'Zwetschgenkuchen', 'Welt'],
#  ['Grundrezept', 'Ganache'],
#  ['Hähnchenbrustfilet', 'Sahne', 'Kräuter', 'Soße'],
#  ['Hackbällchen', 'Kräuter', 'Feta', 'Sauce', 'überbacken'],
#  ['Bananenbrot'],
#  ['Avocado', 'Fries'],
#  ['Omas',
#   'Käsekuchen',
#   'Sultaninen',
#   'Boden',
#   'eigentlich',
#   'schon',
#   'Uhroma'],
#  ['Mohnkuchen', 'locker', 'leicht', 'saftig'],
#  ['Nudeln', 'Sahne', 'Champignons'],
#  ['Schwabentopf', 'Hauses'],
#  ['Gefüllte', 'Spitzpaprika', 'Frischkäse'],
#  ['Torten', 'Schokoladentorte', 'Torte', 'meinem', 'Geburtstag'],
#  ['Champignons', 'Weißweinsauce', 'Reis'],
#  ['Gnocchi', 'selbstgemacht'],
#  ['Senfeier', 'Mutti', 'Oma'],
#  ['Käse', 'Tarteletts', 'Spinat'],
#  ['Berliner', 'Currywurst'],
#  ['schneller', 'Käsekuchen', 'Boden'],
#  ['LowCarb', 'Beeren', 'Minz', 'Limonade'],
#  ['MEIN', 'LAHMACUN', 'Türkische', 'Pizza'],
#  ['Kuchen', 'Schoko', 'Haselnuss', 'Kuchen'],
#  ['Plätzchen', 'Butterteilchen'],
#  ['Auflauf', 'Roter', 'Nudel', 'Hackauflauf', 'Mozzarella'],
#  ['Schneller', 'Quiche', 'Ideal', 'Gäste'],
#  ['Gemüse', 'Nudel', 'Suppe'],
#  ['Apple', 'Crumble', 'engl'],
#  ['Grüner', 'Spargel', 'Backofen'],
#  ['Beschwipster', 'Apfelkuchen'],
#  ['Mamas', 'Bolognese', 'Spaghetti'],
#  ['Grillen', 'Kräuterhähnchen', 'Kugelgrill'],
#  ['Deluxe', 'Schokocreme', 'Torte'],
#  ['Banane', 'Joghurt', 'Buttermilch', 'Smoothie'],
#  ['Gyrosauflauf'],
#  ['Pizzaschnecken', 'Blätterteig'],
#  ['Pasta', 'Diavolo'],
#  ['Halloween', 'Gebiss', 'Deko', 'Kalte', 'Platte', 'Cocktail'],
#  ['Lasagne', 'Forno'],
#  ['Türkische', 'Pizza', 'Lahmacun'],
#  ['Auflauf', 'Spanakopita'],
#  ['Salzbraten'],
#  ['Klassischer', 'Nudelsalat'],
#  ['Gegrillte', 'Champignons', 'Bacon'],
#  ['Pizzateig'],
#  ['Dampfnudeln'],
#  ['TIRAMISU', 'AL', 'LIMONE'],
#  ['Bruschetta',
#   'Brot',
#   'Pane',
#   'per',
#   'bruschette',
#   'selbst',
#   'gebacken',
#   'gelingsicher'],
#  ['Fluffige', 'Waffeln'],
#  ['Zwiebelschnitzelchen', 'Butter', 'Rosenkohl'],
#  ['Tiramisu'],
#  ['Knusper', 'Walnuß', 'Eis'],
#  ['Quark', 'Mandarinen', 'Blechkuchen'],
#  ['Cremiges', 'Hokkaido', 'Süppchen'],
#  ['Toffee', 'Mandelkuchen'],
#  ['Nudeln', 'Schinken', 'Käsesauce', 'Weight', 'Watchers'],
#  ['Käsespätzle', 'anders'],
#  ['Vanille', 'Pudding', 'Kipferl'],
#  ['Pfeffi', 'Kuchen', 'Erwachsene'],
#  ['Advents', 'Ente', 'interessanter', 'Füllung'],
#  ['Porree', 'Kartoffelsuppe', 'Chili', 'Hackbällchen'],
#  ['LOW', 'CARB', 'Puten', 'Gemüse', 'Cannelloni'],
#  ['Schwedische', 'Fleischbällchen', 'Köttbullar', 'Soße'],
#  ['Brötchen'],
#  ['Bruschetta'],
#  ['Bounty', 'Mogel', 'Kuchen'],
#  ['Schoko', 'Cookies'],
#  ...]

# %%
# Add all titles to a single string
all_titles = ""
for title in titlelist:
    for w in title:
        all_titles += w+" "
    all_titles += " \n "

# %%
titlefile = open('word_embeddings/titles.txt', 'w')
titlefile.write(all_titles)
# Out:
# 11487663

# %% [markdown]
# ### Cleaning the preparation steps before training
#
# It usually provides better word embeddings if the model is trained on longer texts instead of single words, as the sequences in which the words occur influences their position in the word embedding's feature space.
#
# However, it is hard to say if the vectors will provide a much higher benefit for this project when trained on the preparation steps instead of the titles only. Thus, we will need to test both models before deciding.
#
# When preparing the text from the preparation steps, we do not need to filter as much as we did in the titles. Stopwords can now be useful to identify relations between entities, as they are part of continuous text instead of short titles.

# %%
preplist = []
for i in range(len(kochbar)):
    prep = kochbar[i]['preparation']
    for char in ['"','-','=','!','(',')','.','♥',',',':','~','„','“','/','–','&','+',';','*','☆','\r']:
        prep = prep.replace(char,' ')
    tmp_list = list(filter(None, prep.split(" ")))   # filter empty elements
    preplist.append(tmp_list) 
preplist
# Out:
# [['1',
#   'Das',
#   'Hackfleisch',
#   'mit',
#   'etwas',
#   'Margarine',
#   'in',
#   'der',
#   'Pfanne',
#   'krümelig',
#   'anbraten',
#   'Zucchini',
#   'waschen',
#   'halbieren',
#   'und',
#   'mit',
#   'einem',
#   'Teelöffel',
#   'die',
#   'Kerne',
#   'entfernen',
#   'dann',
#   'in',
#   'Scheibchen',
#   'schneiden',
#   'dazugeben',
#   'und',
#   'kurz',
#   'mitbraten',
#   'Salzen',
#   'und',
#   'Pfeffern',
#   'Knobi',
#   'auspressen',
#   'dazugeben',
#   'und',
#   'abschmecken',
#   '2',
#   'Alles',
#   'in',
#   'eine',
#   'Auflaufform',
#   'geben',
#   'und',
#   'die',
#   'Spätzle',
#   'unterheben',
#   'Den',
#   'Kräuterfrischkäse',
#   'mit',
#   'der',
#   'Sahne',
#   'und',
#   'den',
#   'Eiern',
#   'glattrühren',
#   'die',
#   'gehackte',
#   'Petersilie',
#   'mit',
#   'einrühren',
#   'Mit',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'und',
#   'Knoblauchgranulat',
#   'abschmecken',
#   'alles',
#   'über',
#   'die',
#   'Hackfleischmischung',
#   'geben',
#   '3',
#   'Im',
#   'vorgeheizten',
#   'Backofen',
#   'mittl',
#   'Schiene',
#   'auf',
#   '200',
#   'Grad',
#   'ca',
#   '30',
#   'Min',
#   'überbacken',
#   'bis',
#   'die',
#   'obere',
#   'Schicht',
#   'leicht',
#   'bräunlich',
#   'wird'],
#  ['1',
#   'Die',
#   'Eier',
#   'trennen',
#   'das',
#   'Eiweiß',
#   'in',
#   'eine',
#   'größere',
#   'Schüssel',
#   'geben',
#   'und',
#   'diese',
#   'in',
#   'den',
#   'Kühlschrank',
#   'stellen',
#   '2',
#   'Den',
#   'Ofen',
#   'auf',
#   '170',
#   'Grad',
#   'Celsius',
#   'vorheizen',
#   'Einen',
#   'ca',
#   '20',
#   'cm',
#   'hohen',
#   'und',
#   '50',
#   'cm',
#   'langen',
#   'Backpapierstreifen',
#   'vorbereiten',
#   '3',
#   'Die',
#   'weiße',
#   'Schokolade',
#   'zerteilen',
#   'und',
#   'in',
#   'große',
#   'Aluminiumschüssel',
#   'geben',
#   'und',
#   'dann',
#   'über',
#   'einem',
#   'heißen',
#   'Wasserbad',
#   'schmelzen',
#   'Verrühren',
#   'bis',
#   'sie',
#   'eine',
#   'glatte',
#   'Masse',
#   'bildet',
#   '4',
#   'Nun',
#   'die',
#   'drei',
#   'Eiweiße',
#   'wieder',
#   'aus',
#   'dem',
#   'Kühlschrank',
#   'holen',
#   'und',
#   'mit',
#   'dem',
#   'Mixer',
#   'zu',
#   'Eischnee',
#   'aufschlagen',
#   '5',
#   'Jetzt',
#   'die',
#   '120',
#   'gr',
#   'Frischkäse',
#   'zur',
#   'Schokolade',
#   'hinzufügen',
#   'und',
#   'beides',
#   'gut',
#   'miteinander',
#   'vermengen',
#   '6',
#   'Anschließend',
#   'die',
#   'drei',
#   'Eigelb',
#   'hinzufügen',
#   'und',
#   'ebenfalls',
#   'gut',
#   'unterrühren',
#   'bis',
#   'die',
#   'Masse',
#   'homogen',
#   'ist',
#   '7',
#   'Danach',
#   '1',
#   '3',
#   'des',
#   'Eischnee',
#   'vorsichtig',
#   'unterheben',
#   'und',
#   'langsam',
#   'gut',
#   'durchmischen',
#   'Das',
#   'gleiche',
#   'nacheinander',
#   'mit',
#   'den',
#   'beiden',
#   'anderen',
#   'Dritteln',
#   'des',
#   'Eischnees',
#   'tun',
#   '8',
#   'Den',
#   'Backpapierstreifen',
#   'fein',
#   'mit',
#   'Butter',
#   'einreiben',
#   'damit',
#   'der',
#   'Teig',
#   'sich',
#   'bewegen',
#   'kann',
#   'ohne',
#   'beim',
#   'Backen',
#   'zu',
#   'brechen',
#   '9',
#   'Die',
#   'Backform',
#   '15',
#   'cm',
#   'am',
#   'besten',
#   'mit',
#   'hohen',
#   'Rändern',
#   'unten',
#   'mit',
#   'einem',
#   'passenden',
#   'aus',
#   'Backpapier',
#   'ausgeschnittenen',
#   'Kreis',
#   'belegen',
#   'und',
#   'den',
#   'eingebutterten',
#   'Streifen',
#   'in',
#   'die',
#   'Seite',
#   'der',
#   'Form',
#   'legen',
#   '10',
#   'Die',
#   'Teig',
#   'Masse',
#   'in',
#   'die',
#   'Form',
#   'geben',
#   'ein',
#   'paar',
#   'Mal',
#   'auf',
#   'die',
#   'Arbeitsfläche',
#   'aufklopfen',
#   'um',
#   'evtl',
#   'Luftbläschen',
#   'nach',
#   'oben',
#   'steigen',
#   'zu',
#   'lassen',
#   '11',
#   'Die',
#   'Backform',
#   'auf',
#   'ein',
#   'hohes',
#   'Backblech',
#   'geben',
#   'und',
#   'letzteres',
#   'mit',
#   'heißem',
#   'Wasser',
#   'füllen',
#   'Nur',
#   'soviel',
#   'dass',
#   'nichts',
#   'überschwappt',
#   'auf',
#   'dem',
#   'Weg',
#   'zum',
#   'Ofen',
#   '12',
#   'Nun',
#   'wird',
#   'der',
#   'Teig',
#   'in',
#   'drei',
#   'Phasen',
#   'gebacken',
#   '15',
#   'Minuten',
#   'bei',
#   '170',
#   'Grad',
#   'Celsius',
#   '15',
#   'Minuten',
#   'bei',
#   '160',
#   'Grad',
#   'Celsius',
#   'dann',
#   'die',
#   'Beheizung',
#   'ganz',
#   'abdrehen',
#   'und',
#   'nochmal',
#   '15',
#   'Minuten',
#   'in',
#   'der',
#   'Resthitze',
#   'backen',
#   '13',
#   'Dann',
#   'aus',
#   'dem',
#   'Ofen',
#   'nehmen',
#   'und',
#   'auf',
#   'einem',
#   'Drahtgitter',
#   'abkühlen',
#   'lassen',
#   '14',
#   'Man',
#   'kann',
#   'den',
#   'Kuchen',
#   'noch',
#   'mit',
#   'Puderzucken',
#   'bestreuen',
#   'wenn',
#   'man',
#   'Lust',
#   'hat',
#   'Fertig'],
#  ['1',
#   'Die',
#   'Zwiebeln',
#   'und',
#   'das',
#   'Hack',
#   'in',
#   'dem',
#   'Olivenöl',
#   'anbraten',
#   '2',
#   'Die',
#   'Tomatenstücke',
#   'geschälte',
#   'Tomaten',
#   'Tomatenmark',
#   'Knoblauch',
#   'Bohnen',
#   'Mais',
#   'Lorbeerbblätter',
#   'Chili',
#   'Rotwein',
#   'Kreuzkümmel',
#   'Salz',
#   'Pfeffer',
#   'Zucker',
#   'und',
#   'die',
#   'Brühe',
#   'hinzugeben',
#   'Bei',
#   'Bedarf',
#   'etwas',
#   'Wasser',
#   'hinzugeben',
#   'wenn',
#   'das',
#   'Chili',
#   'zu',
#   'dick',
#   'wird',
#   '3',
#   'Jetzt',
#   'die',
#   'Geheim',
#   'Zutat',
#   'Kakaopulver',
#   'Nesquick',
#   'hinzugeben',
#   'Dadurch',
#   'wird',
#   'das',
#   'Chili',
#   'schön',
#   'Cremig',
#   'bekommt',
#   'eine',
#   'schöne',
#   'dunkle',
#   'Farbe',
#   'und',
#   'gibt',
#   'einen',
#   'super',
#   'Geschmack',
#   '4',
#   'Das',
#   'ganze',
#   'jetzt',
#   'noch',
#   '45',
#   'min',
#   'auf',
#   'kleiner',
#   'Flamme',
#   'köcheln',
#   'lassen',
#   'damit',
#   'alles',
#   'schön',
#   'duchziehen',
#   'kann',
#   'Nach',
#   'Gechmack',
#   'durch',
#   'Zugabe',
#   'von',
#   'weiterem',
#   'Chili',
#   'die',
#   'Schärfe',
#   'erhöhen',
#   'aber',
#   'nicht',
#   'Übertreiben',
#   '5',
#   'Wünsche',
#   'Guten',
#   'Appetit',
#   'und',
#   'viel',
#   'Spass',
#   'beim',
#   'Nachkochen',
#   '6',
#   'Bild',
#   'folgt'],
#  ['1',
#   'Kartoffeln',
#   'schälen',
#   'und',
#   'auf',
#   'einem',
#   'Gurkenhobel',
#   'in',
#   'feine',
#   'Scheiben',
#   'hobeln',
#   'od',
#   'einfach',
#   'sehr',
#   'dünne',
#   'Scheiben',
#   'schneiden',
#   'Eine',
#   'Auflaufform',
#   'fetten',
#   'und',
#   'die',
#   'Kartoffeln',
#   'dachziegelartig',
#   'einschichten',
#   'Mit',
#   'den',
#   'Gewürzen',
#   'und',
#   'Speck',
#   'bestreuen',
#   '2',
#   'Milch',
#   'und',
#   'Sahne',
#   'verrühren',
#   'und',
#   'ggfs',
#   'eine',
#   'Knoblauchzehe',
#   'reinpressen',
#   'und',
#   'über',
#   'die',
#   'Kartoffelscheiben',
#   'gießen',
#   'Alles',
#   'mit',
#   'Käse',
#   'bestreuen',
#   'und',
#   'im',
#   'vorgeheizten',
#   'Ofen',
#   '200',
#   'Grad',
#   'Umluft',
#   '180',
#   'Grad',
#   'für',
#   '40',
#   'Min',
#   'überbacken'],
#  ['1',
#   'Aus',
#   'Mehl',
#   'Backpulver',
#   'Zucker',
#   'Vanillezucker',
#   'Butter',
#   'und',
#   'Eier',
#   'einen',
#   'Rührteig',
#   'herstellen',
#   'diesen',
#   'in',
#   'eine',
#   'Springform',
#   'füllen',
#   'und',
#   'bei',
#   '180',
#   'C',
#   'ca',
#   '20Min',
#   'backen',
#   'in',
#   'dieser',
#   'zeit',
#   'Butter',
#   'Zucker',
#   'Sahne',
#   'Honig',
#   'in',
#   'einem',
#   'Topf',
#   'zum',
#   'schmelzen',
#   'bringen',
#   'dann',
#   'die',
#   'Mandeln',
#   'dazu',
#   'geben',
#   'und',
#   'einmal',
#   'aukochen',
#   'lassen',
#   'Nach',
#   '20',
#   'min',
#   'Backzeit',
#   'Die',
#   'Mandelmischung',
#   'auf',
#   'dem',
#   'Kuchen',
#   'verteilen',
#   'und',
#   'nochmals',
#   '10',
#   '15',
#   'Min',
#   'backen',
#   'und',
#   'auskühlen',
#   'lassen',
#   '2',
#   'Die',
#   'Paradiescreme',
#   'nach',
#   'Packungsanleitung',
#   'zubereiten',
#   'aber',
#   'anstatt',
#   'mit',
#   'Milch',
#   'mit',
#   'der',
#   'Sahne',
#   'aufschlagen',
#   'Den',
#   'Kuchen',
#   'einmal',
#   'Quer',
#   'durschneiden',
#   'und',
#   'mit',
#   'der',
#   'Creme',
#   'füllen',
#   'Lecker',
#   'Lecker',
#   'Lecker'],
#  ['1',
#   'Milch',
#   'mit',
#   'dem',
#   'Mehl',
#   'gut',
#   'verrühren',
#   'und',
#   'die',
#   'Eier',
#   'dazu',
#   'geben',
#   'Salz',
#   'Zucker',
#   'und',
#   'einen',
#   'EL',
#   'ÖL',
#   'dazugeben',
#   'und',
#   'nochmal',
#   'kräftig',
#   'verrühren',
#   'bis',
#   'man',
#   'einen',
#   'glatten',
#   'Teig',
#   'ohne',
#   'Klümpchen',
#   'hat',
#   'Ich',
#   'neheme',
#   'dazu',
#   'einen',
#   'Pürrierstab',
#   '2',
#   'Eine',
#   'bechichtete',
#   'Pfanne',
#   'erhitzen',
#   'mittlere',
#   'Hitze',
#   'Etwas',
#   'Küchenpapier',
#   'mit',
#   'Öl',
#   'tränken',
#   'und',
#   'die',
#   'heiße',
#   'Pfanne',
#   'damit',
#   'ausreiben',
#   '3',
#   'Teig',
#   'in',
#   'der',
#   'Pfanne',
#   'gleichmäßig',
#   'verteilen',
#   'sodas',
#   'ein',
#   'schöner',
#   'runder',
#   'Pfannkuchen',
#   'entsteht',
#   'Wenn',
#   'die',
#   'Unterseite',
#   'goldgelb',
#   'ist',
#   'den',
#   'Pfannkuchen',
#   'wenden',
#   '4',
#   'Jetzt',
#   'kommt',
#   'der',
#   'Trick',
#   'mit',
#   'dem',
#   'Topf',
#   'Ich',
#   'stelle',
#   'jetzt',
#   'einen',
#   'Topf',
#   'der',
#   'ungefähr',
#   'so',
#   'groß',
#   'wie',
#   'der',
#   'Pfannkuchen',
#   'ist',
#   'auf',
#   'den',
#   'Pfannkuchen',
#   'in',
#   'die',
#   'Pfanne',
#   'Der',
#   'Topf',
#   'sollte',
#   'natürlich',
#   'super',
#   'sauber',
#   'sein',
#   'So',
#   'wird',
#   'der',
#   'Pfannkuchen',
#   'auch',
#   'von',
#   'der',
#   'anderen',
#   'Seite',
#   'schön',
#   'gleichmäßig',
#   'goldgelb',
#   'Sollen',
#   'die',
#   'Pfannkuchen',
#   'gefüllt',
#   'werden',
#   'z',
#   'B',
#   'Pfannkuchenröllchen',
#   'mit',
#   'Lachs',
#   's',
#   'Kochbuch',
#   'auf',
#   'einen',
#   'Gitter',
#   'auskühlen',
#   'lassen',
#   '5',
#   'Mann',
#   'kann',
#   'das',
#   'Rezept',
#   'nach',
#   'belieben',
#   'varieiren',
#   'Mehr',
#   'Milch',
#   'gibt',
#   'sehr',
#   'dünne',
#   'Pfannkuche',
#   'Crepp',
#   'Wer',
#   'es',
#   'dick',
#   'und',
#   'flüffig',
#   'mag',
#   'kann',
#   'die',
#   'Eier',
#   'trennen',
#   'und',
#   'das',
#   'Eiweiß',
#   'schaumig',
#   'schlagen',
#   'und',
#   'unter',
#   'den',
#   'Teig',
#   'heben',
#   '6',
#   'Mann',
#   'kann',
#   'auch',
#   'nach',
#   'belieben',
#   'Zutaten',
#   'direkt',
#   'mit',
#   'in',
#   'den',
#   'Teig',
#   'geben',
#   'Z',
#   'b',
#   'Apfelstückchen',
#   'und',
#   'Rosinen',
#   'dann',
#   'noch',
#   'etwas',
#   'Backpulver',
#   'in',
#   'den',
#   'Teig',
#   'oder',
#   'Herzhaft',
#   'mit',
#   'angebratenem',
#   'Speck',
#   'dann',
#   'das',
#   'Öl',
#   'im',
#   'Teig',
#   'weglassen'],
#  ['1',
#   'Palmin',
#   'Butter',
#   'und',
#   'Schokolade',
#   'langsam',
#   'im',
#   'Topf',
#   'zergehen',
#   'lassen',
#   'Kokosflocken',
#   'und',
#   'Eierlikör',
#   'hineinrühren',
#   'und',
#   'etwas',
#   'abkühlen',
#   'lassen',
#   '2',
#   'Kugeln',
#   'formen',
#   'und',
#   'in',
#   'Kokosflocken',
#   'wenden'],
#  ['1',
#   'Backofen',
#   'auf',
#   '200Grad',
#   'vorheizen',
#   'und',
#   'Muffinblech',
#   'mit',
#   'Papierförmchen',
#   'auslegen',
#   '2',
#   'Alle',
#   'Zutaten',
#   'in',
#   'einer',
#   'Schüssel',
#   'verrühren',
#   'und',
#   'in',
#   'die',
#   'Papierförmchen',
#   'füllen',
#   '3',
#   'Man',
#   'kann',
#   'auch',
#   'noch',
#   'ganz',
#   'viele',
#   'Zutaten',
#   'in',
#   'den',
#   'Teig',
#   'mischen',
#   'z',
#   'B',
#   'für',
#   'Wintermuffins',
#   'einen',
#   'kleingeschnittenen',
#   'Apfel',
#   'Rosinen',
#   'und',
#   'etwas',
#   'Zimt',
#   'oder',
#   'eine',
#   'zerdrückte',
#   'Banane',
#   'und',
#   'Kakaopulver',
#   'Auch',
#   'lecker',
#   'wird´s',
#   'mit',
#   'Blaubeeren',
#   'oder',
#   'Schokostückchen',
#   '4',
#   'Ca',
#   '15',
#   '20',
#   'Minuten',
#   'backen',
#   '5',
#   'Zum',
#   'Schluss',
#   'die',
#   'Muffins',
#   'aus',
#   'dem',
#   'Blech',
#   'holen',
#   'und',
#   'auf',
#   'einem',
#   'Teller',
#   'abkühlen',
#   'lassen',
#   'FERTIG'],
#  ['1',
#   'Zunächst',
#   'das',
#   'Hackfleisch',
#   'in',
#   'einen',
#   'großen',
#   'Suppentopf',
#   'geben',
#   'und',
#   'ca',
#   '5',
#   'Minuten',
#   'anbraten',
#   'In',
#   'der',
#   'Zwischenzeit',
#   'wird',
#   'der',
#   'Porree',
#   'gewaschen',
#   'in',
#   'dünne',
#   'Ringe',
#   'geschnitten',
#   'und',
#   'zum',
#   'Hackfleisch',
#   'gegeben',
#   'Wenn',
#   'alles',
#   'schön',
#   'angebraten',
#   'ist',
#   'die',
#   'Gemüsebrühe',
#   'aufgießen',
#   '2',
#   'Nach',
#   'und',
#   'nach',
#   'den',
#   'Schmelzkäse',
#   'etwas',
#   'zerkleinert',
#   'hinzugeben',
#   'und',
#   'kräftig',
#   'rühren',
#   'bis',
#   'der',
#   'Käse',
#   'komplett',
#   'aufgelöst',
#   'ist',
#   'Solange',
#   'Käse',
#   'hinzugeben',
#   'bis',
#   'die',
#   'gewünschte',
#   'Dicke',
#   'erreicht',
#   'ist',
#   'Mit',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'würzen',
#   '3',
#   'Nach',
#   'dem',
#   'Abkühlen',
#   'dickt',
#   'die',
#   'Suppe',
#   'noch',
#   'etwas',
#   'nach',
#   'Entweder',
#   'zuvor',
#   'etwas',
#   'dünner',
#   'zubereiten',
#   'oder',
#   'beim',
#   'späteren',
#   'Erwärmen',
#   'noch',
#   'mit',
#   'Brühe',
#   'oder',
#   'Wasser',
#   'anreichern'],
#  ['1',
#   'Eier',
#   'trennen',
#   'Das',
#   'Eigelb',
#   'mit',
#   'dem',
#   'Mehl',
#   'Backpulver',
#   'und',
#   'der',
#   'Milch',
#   'zu',
#   'einem',
#   'glatten',
#   'dicken',
#   'Teig',
#   'rühren',
#   'Das',
#   'Eiweiß',
#   'mit',
#   'dem',
#   'Salz',
#   'steif',
#   'schlagen',
#   'und',
#   'unter',
#   'den',
#   'Teig',
#   'heben',
#   'Nun',
#   'immer',
#   'ein',
#   'Schöpflöffel',
#   'Teig',
#   'in',
#   'einer',
#   'Pfanne',
#   'gold',
#   'backen',
#   'Jetzt',
#   'kann',
#   'jeder',
#   'seinen',
#   'Pancake',
#   'nach',
#   'belieben',
#   'mit',
#   'Ahornsirup',
#   'Bananen',
#   'Äpfelchen',
#   'etc',
#   'verfeinern',
#   '2',
#   'ICh',
#   'wünsche',
#   'einen',
#   'guten',
#   'Appetit',
#   'PS',
#   'Über',
#   'eine',
#   'Rückmeldung',
#   'würde',
#   'ich',
#   'mich',
#   'sehr',
#   'freuen'],
#  ['1',
#   'Aus',
#   'den',
#   'angegebenen',
#   'Zutaten',
#   'einen',
#   'Knetteig',
#   'bereiten',
#   'den',
#   'Boden',
#   'und',
#   'Rand',
#   'einer',
#   'eingefetteten',
#   'Springform',
#   'damit',
#   'auslegen',
#   'und',
#   'bei',
#   '200Grad',
#   'ca',
#   '10',
#   'Minuten',
#   'vorbacken',
#   'Dach',
#   'alle',
#   'Zutaten',
#   'bis',
#   'auf',
#   'das',
#   'Eiweiß',
#   'mit',
#   'dem',
#   'Handrührgerät',
#   'verrühren',
#   'Die',
#   '4',
#   'Eiweiß',
#   'steif',
#   'schlagen',
#   'und',
#   'vorsichtig',
#   'unter',
#   'die',
#   'Quarkmasse',
#   'heben',
#   'Bei',
#   '175',
#   'Grad',
#   '60',
#   '70',
#   'Minuten',
#   'backen',
#   'Nach',
#   'belieben',
#   'mit',
#   'Puderzucker',
#   'bestäuben',
#   '2',
#   'schmeckt',
#   'auch',
#   'super',
#   'mit',
#   'Rumrosinen',
#   'dafür',
#   'einfach',
#   'ein',
#   'Packetrumrosinen',
#   'vor',
#   'dem',
#   'Eiweiß',
#   'unterrühren',
#   'und',
#   'danach',
#   'das',
#   'Eiweiß',
#   'unterheben',
#   'Mag',
#   'ich',
#   'am',
#   'liebsten',
#   '3',
#   'schmeckt',
#   'auch',
#   'gut',
#   'mit',
#   'pfirsichen',
#   'hierzu',
#   'einfach',
#   'eine',
#   'dose',
#   'Pfirsiche',
#   'kleinschneiden',
#   'nach',
#   'dem',
#   'der',
#   'Boden',
#   'fertig',
#   'ist',
#   'ca',
#   '1cm',
#   'der',
#   'füllung',
#   'auftragen',
#   'dann',
#   'die',
#   'Pfirsiche',
#   'und',
#   'danach',
#   'den',
#   'rest',
#   'der',
#   'füllung'],
#  ['1',
#   'Blätterteig',
#   'in',
#   'Dreiecke',
#   'schneiden',
#   'und',
#   'in',
#   'Sternform',
#   'auf',
#   'einem',
#   'Backblech',
#   'auslegen',
#   '2',
#   'Blätterteig',
#   'mit',
#   'Nutella',
#   'beschmieren',
#   'und',
#   'mit',
#   'Schokoraspeln',
#   'bestreuen',
#   '3',
#   'Eine',
#   'Banane',
#   'in',
#   'Scheiben',
#   'schneiden',
#   'und',
#   'auf',
#   'dem',
#   'Blätterteig',
#   'verteilen',
#   '4',
#   'Erdbeeren',
#   'ebenfalls',
#   'in',
#   'Scheiben',
#   'schneiden',
#   'und',
#   'auf',
#   'dem',
#   'Blätterteig',
#   'verteilen',
#   '4',
#   'Mandelblätter',
#   'über',
#   'den',
#   'Blätterteig',
#   'streuen',
#   '5',
#   'Ecken',
#   'des',
#   'Blätterteig',
#   'Sterns',
#   'nach',
#   'innen',
#   'falten',
#   'und',
#   'das',
#   'so',
#   'entstandene',
#   'Blätterteig',
#   'Päckchen',
#   'mit',
#   'Eiklar',
#   'bestreichen',
#   '6',
#   'Bei',
#   '180',
#   'Grad',
#   'für',
#   '25',
#   'Minuten',
#   'backen'],
#  ['1',
#   'Wer',
#   'Aufback',
#   'Ciabatta',
#   'nimmt',
#   'muss',
#   'die',
#   'als',
#   'erstes',
#   'nach',
#   'Vorschrift',
#   'backen',
#   'und',
#   'dann',
#   'etwas',
#   'auskühlen',
#   'lassen',
#   '2',
#   'Ansonsten',
#   'als',
#   'erstes',
#   'die',
#   'Zwiebel',
#   'in',
#   'feine',
#   'Würfel',
#   'schneiden',
#   'und',
#   'in',
#   'eine',
#   'Schüssel',
#   'geben',
#   '3',
#   'Dann',
#   'die',
#   'Tomaten',
#   'halbieren',
#   'den',
#   'Strunk',
#   'und',
#   'das',
#   'innere',
#   'weiche',
#   'entfernen',
#   'Nun',
#   'werden',
#   'die',
#   'Tomaten',
#   'auch',
#   'in',
#   'kleine',
#   'Würfel',
#   'geschnitten',
#   'und',
#   'kommen',
#   'mit',
#   'zu',
#   'den',
#   'Zwiebeln',
#   '4',
#   'Jetzt',
#   'müssen',
#   'ein',
#   'paar',
#   'Blätter',
#   'frischer',
#   'Basilikum',
#   'klein',
#   'geschnitten',
#   'werden',
#   'das',
#   'kommt',
#   'dann',
#   'mit',
#   'zu',
#   'den',
#   'anderen',
#   'in',
#   'die',
#   'Schüssel',
#   '5',
#   'Jetzt',
#   'schneidet',
#   'man',
#   'etwas',
#   'Knoblauch',
#   'in',
#   'Würfel',
#   'und',
#   'gibt',
#   'diesen',
#   'mit',
#   'etwas',
#   'Olivenöl',
#   'in',
#   'einen',
#   'Mörser',
#   'Dann',
#   'etwas',
#   'Salz',
#   'dazu',
#   'und',
#   'gut',
#   'mörsern',
#   'Wer',
#   'keinen',
#   'Mörser',
#   'hat',
#   'muss',
#   'den',
#   'Knoblauch',
#   'ganz',
#   'fein',
#   'schneiden',
#   'und',
#   'mit',
#   'Olivenöl',
#   'mischen',
#   '6',
#   'Dann',
#   'wird',
#   'das',
#   'Ciabatta',
#   'in',
#   'etwas',
#   'dickere',
#   'Scheiben',
#   'geschnitten',
#   'und',
#   'auf',
#   'ein',
#   'Blech',
#   'gelegt',
#   'Die',
#   'Scheiben',
#   'werden',
#   'dann',
#   'mit',
#   'der',
#   'Knoblauch',
#   'Öl',
#   'Mischung',
#   'mit',
#   'einem',
#   'Pinsel',
#   'bestrichen',
#   'Dann',
#   'kommen',
#   'sie',
#   'kurz',
#   'bei',
#   '200',
#   'Grad',
#   'in',
#   'den',
#   'Backofen',
#   'bis',
#   'sie',
#   'leicht',
#   'braun',
#   'sind',
#   '7',
#   'Jetzt',
#   'erst',
#   'mischt',
#   'man',
#   'die',
#   'Tomaten',
#   'Zwiebeln',
#   'und',
#   'den',
#   'Basilikum',
#   'in',
#   'der',
#   'Schüssel',
#   'durch',
#   'und',
#   'gibt',
#   'noch',
#   'etwas',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'dazu',
#   'Wenn',
#   'man',
#   'dies',
#   'zu',
#   'früh',
#   'macht',
#   'wird',
#   'die',
#   'Masse',
#   'matschig',
#   'deshalb',
#   'erst',
#   'kurz',
#   'vor',
#   'dem',
#   'Servieren',
#   '8',
#   'Jetzt',
#   'kommt',
#   'die',
#   'Tomatenmischung',
#   'einfach',
#   'auf',
#   'die',
#   'Brotscheiben',
#   'und',
#   'man',
#   'kann',
#   'servieren',
#   'Ist',
#   'eine',
#   'leckere',
#   'Vorspeise',
#   'z',
#   'B',
#   'vor',
#   'Spaghetti',
#   'Bolognese'],
#  ['Die',
#   'Milchmädchencreme',
#   'mit',
#   'den',
#   'Kokosraspeln',
#   'vermischen',
#   'bis',
#   'es',
#   'eine',
#   'gleichmäßige',
#   'Masse',
#   'ist',
#   'Dann',
#   'die',
#   'Masse',
#   'zu',
#   'Kugeln',
#   'formen',
#   'und',
#   'in',
#   'die',
#   'Mitte',
#   'eine',
#   'Mandel',
#   'geben',
#   'Auf',
#   'einem',
#   'Blech',
#   'ca',
#   '3',
#   '4',
#   'Std',
#   'trocknen',
#   'lassen',
#   'Wer',
#   'möchte',
#   'kann',
#   'die',
#   'Pralinen',
#   'dann',
#   'auch',
#   'nochmal',
#   'in',
#   'Kokosraspeln',
#   'wenden',
#   'Für',
#   'alle',
#   'die',
#   'es',
#   'nicht',
#   'kennen',
#   'Milchmädchen',
#   'ist',
#   'gezuckerte',
#   'Kondensmilch',
#   'und',
#   'man',
#   'solte',
#   'sie',
#   'in',
#   'jedem',
#   'großen',
#   'Supermarkt',
#   'bekommen'],
#  ['1',
#   'Als',
#   'erstes',
#   'die',
#   'rote',
#   'Zwiebeln',
#   'schälen',
#   'und',
#   'fein',
#   'hacken',
#   'die',
#   'Sellereistangen',
#   'klein',
#   'schneiden',
#   'die',
#   'Möhren',
#   'schälen',
#   'und',
#   'grob',
#   'reiben',
#   'Das',
#   'Gemüse',
#   'im',
#   'Topf',
#   'mit',
#   'reichlich',
#   'Olivenöl',
#   'andünsten',
#   '2',
#   'Wir',
#   'verwenden',
#   'drei',
#   'verschiedenen',
#   'Fleischsorten',
#   'das',
#   'gibt',
#   'den',
#   'besonderen',
#   'Geschmack',
#   'Das',
#   'Fleisch',
#   'zum',
#   'Gemüse',
#   'geben',
#   'und',
#   'mit',
#   'anbraten',
#   'alles',
#   'salzen',
#   'und',
#   'pfeffern',
#   'Jetzt',
#   'mit',
#   'einem',
#   'Glas',
#   'Rotwein',
#   'ablöschen',
#   'anschließend',
#   'das',
#   'Tomatenmark',
#   'dazugeben',
#   '3',
#   'Dann',
#   'so',
#   'viel',
#   'passierte',
#   'Tomaten',
#   'darauf',
#   'geben',
#   'dass',
#   'alles',
#   'gut',
#   'bedeckt',
#   'ist',
#   'Für',
#   'die',
#   'Würze',
#   'geben',
#   'wir',
#   '2',
#   'Lorbeerblätter',
#   'dazu',
#   'die',
#   'wir',
#   'vorher',
#   'kurz',
#   'anreißen',
#   'damit',
#   'sie',
#   'möglichst',
#   'viel',
#   'Aroma',
#   'an',
#   'die',
#   'Soße',
#   'abgeben',
#   'Wer',
#   'hat',
#   'gibt',
#   'noch',
#   'frisches',
#   'Basilikum',
#   'dazu',
#   'natürlich',
#   'geht',
#   'auch',
#   'getrocknetes',
#   '4',
#   'Das',
#   'Ganze',
#   'mit',
#   'geschlossenem',
#   'Deckel',
#   'am',
#   'besten',
#   '5',
#   'Stunden',
#   'auf',
#   'ganz',
#   'niedriger',
#   'Stufe',
#   'ziehen',
#   'lassen',
#   'Die',
#   'Soße',
#   'kann',
#   'man',
#   'natürlich',
#   'auch',
#   'schon',
#   'am',
#   'Vortag',
#   'zubereiten',
#   'damit',
#   'sie',
#   'Zeit',
#   'zum',
#   'Ziehen',
#   'hat',
#   'und',
#   'sie',
#   'dann',
#   'nochmal',
#   'erwärmen',
#   '5',
#   'Die',
#   'Spaghetti',
#   'in',
#   'Salzwasser',
#   'kochen',
#   'allerdings',
#   '2',
#   'Minuten',
#   'weniger',
#   'als',
#   'es',
#   'auf',
#   'der',
#   'Packung',
#   'angegeben',
#   'steht',
#   'Die',
#   'Nudeln',
#   'werden',
#   'später',
#   'in',
#   'der',
#   'fertigen',
#   'Soße',
#   'nachgegart',
#   'Eine',
#   'Tasse',
#   'Nudelwasser',
#   'abschöpfen',
#   'Nach',
#   '5',
#   'Minuten',
#   'Kochzeit',
#   'dann',
#   'die',
#   'Spaghetti',
#   'abgießen',
#   'NICHT',
#   'kalt',
#   'abschrecken',
#   'Die',
#   'abgetropften',
#   'Nudeln',
#   'gibt',
#   'man',
#   'zurück',
#   'in',
#   'den',
#   'Topf',
#   'und',
#   'vermengt',
#   'sie',
#   'mit',
#   'dem',
#   'abgeschöpften',
#   'Nudelwasser',
#   'und',
#   'einer',
#   'großen',
#   'Portion',
#   'der',
#   'Fleischsoße',
#   'Das',
#   'Ganze',
#   'noch',
#   'so',
#   'lange',
#   'weiter',
#   'köcheln',
#   'lassen',
#   'bis',
#   'die',
#   'Nudeln',
#   'weich',
#   'genug',
#   'sind',
#   '6',
#   'Mit',
#   'einem',
#   'weiteren',
#   'Löffel',
#   'Hackfleisch',
#   'Soße',
#   'und',
#   'je',
#   'nach',
#   'Geschmack',
#   'mit',
#   'geriebenem',
#   'Parmesankäse',
#   'servieren'],
#  ['1',
#   'Alles',
#   'zusammenrühren',
#   'und',
#   'soviel',
#   'Milch',
#   'hinzugeben',
#   'dass',
#   'es',
#   'ein',
#   'glatter',
#   'Teig',
#   'wird',
#   'uvgii2',
#   'In',
#   'einer',
#   'Pfanne',
#   'etwas',
#   'Öl',
#   'oder',
#   'Margarine',
#   'Butter',
#   'erwärmen',
#   'Ein',
#   'Schöpflöffel',
#   'voll',
#   'Pfannkuchenteig',
#   'hineingeben',
#   'Beide',
#   'Seiten',
#   'goldbraun',
#   'backen',
#   '3',
#   'Nun',
#   'können',
#   'sie',
#   'die',
#   'Pfannkuchen',
#   'mit',
#   'Marmelade',
#   'oder',
#   'etwas',
#   'anderem',
#   'servieren'],
#  ['1',
#   'Nudelwasser',
#   'aufsetzen',
#   'und',
#   'zum',
#   'Kochen',
#   'bringen',
#   'Dann',
#   'Nudeln',
#   'und',
#   'grobes',
#   'Meersalz',
#   'zugeben',
#   'und',
#   'bis',
#   'kurz',
#   'vor',
#   'Al',
#   'Dente',
#   'kochen',
#   '2',
#   'In',
#   'der',
#   'Zwischenzeit',
#   'den',
#   'Schinken',
#   'in',
#   'Streifen',
#   'schneiden',
#   'nicht',
#   'zu',
#   'dünn',
#   'oder',
#   'zu',
#   'klein',
#   'So',
#   'wie',
#   'auf',
#   'dem',
#   'Foto',
#   'Die',
#   'Eier',
#   'mit',
#   'einer',
#   'Prise',
#   'Pfeffer',
#   'einem',
#   'Esslöffel',
#   'Pecorino',
#   'und',
#   'einem',
#   'Esslöffel',
#   'Parmesan',
#   'verquirlen',
#   '3',
#   'Pfanne',
#   'erhitzen',
#   'einen',
#   'kleinen',
#   'Esslöffel',
#   'Olivenöl',
#   'in',
#   'die',
#   'Pfanne',
#   'geben',
#   'und',
#   'den',
#   'Schinken',
#   'darin',
#   'mit',
#   'einer',
#   'kleinen',
#   'Prise',
#   'Pfeffer',
#   'anbraten',
#   '4',
#   'Die',
#   'Nudeln',
#   'über',
#   'einem',
#   'Topf',
#   'abgießen',
#   'um',
#   'das',
#   'Wasser',
#   'aufzufangen',
#   'Dann',
#   'die',
#   'Nudeln',
#   'direkt',
#   'in',
#   'die',
#   'Pfanne',
#   'geben',
#   'und',
#   'eine',
#   'Kelle',
#   'voll',
#   'vom',
#   'Nudelwasser',
#   'zugeben',
#   'Das',
#   'heiße',
#   'Nudelwasser',
#   'sorgt',
#   'für',
#   'eine',
#   'gute',
#   'Bindung',
#   '5',
#   'Das',
#   'verquirlte',
#   'Ei',
#   'zugeben',
#   'und',
#   'sofort',
#   'gut',
#   'durchschwenken',
#   '6',
#   'Jetzt',
#   'einen',
#   'Esslöffel',
#   'voll',
#   'Pecorino',
#   'und',
#   'Parmesan',
#   'zugeben',
#   'und',
#   'nochmal',
#   'eine',
#   'kleine',
#   'Kelle',
#   'Nudelwasser',
#   'Wieder',
#   'gut',
#   'durchschwenken',
#   'bis',
#   'eine',
#   'gute',
#   'Bindung',
#   'entstanden',
#   'ist',
#   '7',
#   'Vorgewärmte',
#   'Teller',
#   'bereit',
#   'stellen',
#   'und',
#   'zuerst',
#   'die',
#   'Nudeln',
#   'mit',
#   'einer',
#   'Zange',
#   'oder',
#   'Fleischgabel',
#   'aufdrehen',
#   'und',
#   'auf',
#   'dem',
#   'Teller',
#   'anrichten',
#   'Dann',
#   'einfach',
#   'den',
#   'Rest',
#   'direkt',
#   'aus',
#   'der',
#   'Pfanne',
#   'darüber',
#   'kippen',
#   'Das',
#   'ist',
#   'gut',
#   'für',
#   'die',
#   'Optik',
#   'weil',
#   'dann',
#   'die',
#   'Schinkenstücke',
#   'oben',
#   'drauf',
#   'liegen',
#   'und',
#   'nicht',
#   'in',
#   'den',
#   'nudeln',
#   'untergehen',
#   '8',
#   'Zum',
#   'Schluss',
#   'nochmal',
#   'etwas',
#   'Parmesan',
#   'und',
#   'Pecorino',
#   'darüber',
#   'streuen',
#   'und',
#   'fertig',
#   'ACHTUNG',
#   'Mit',
#   'Salz',
#   'ganz',
#   'vorsichtig',
#   'umgehen',
#   'oder',
#   'besser',
#   'ganz',
#   'weglassen',
#   'da',
#   'der',
#   'Käse',
#   'das',
#   'Nudelwasser',
#   'und',
#   'der',
#   'Schinken',
#   'schon',
#   'salzig',
#   'genug',
#   'sind',
#   '9',
#   'Ich',
#   'muß',
#   'noch',
#   'anmerken',
#   'dass',
#   'sicherlich',
#   'auch',
#   'Carbonara',
#   'mit',
#   'Sahne',
#   'oder',
#   'anderen',
#   'Zutaten',
#   'schmecken',
#   'können',
#   'Wenn',
#   'man',
#   'es',
#   'dann',
#   'allerdings',
#   'ganz',
#   'genau',
#   'nimmt',
#   'sind',
#   'es',
#   'halt',
#   'keine',
#   'echten',
#   'Carbonara',
#   'mehr',
#   'sondern',
#   'eher',
#   'die',
#   'deutsche',
#   'Version',
#   'einer',
#   'Carbonara',
#   'Ich',
#   'hoffe',
#   'dass',
#   'sich',
#   'jetzt',
#   'niemand',
#   'angegriffen',
#   'fühlt',
#   'und',
#   'wünsche',
#   'trotzdem',
#   'einen',
#   'guten',
#   'Appetit',
#   'und',
#   'viel',
#   'Spaß',
#   'beim',
#   'nachkochen'],
#  ['1',
#   'Am',
#   'besten',
#   'benutzt',
#   'man',
#   'für',
#   'Brownies',
#   'eine',
#   'flache',
#   'Auflaufform',
#   'aus',
#   'Blech',
#   'die',
#   'werden',
#   'in',
#   'den',
#   'USA',
#   'zum',
#   'Backen',
#   'benutzt',
#   'Man',
#   'kann',
#   'sie',
#   'natürlich',
#   'auch',
#   'auf',
#   'dem',
#   'Blech',
#   'machen',
#   'muss',
#   'dann',
#   'aber',
#   'die',
#   'Menge',
#   'anpassen',
#   'damit',
#   'sie',
#   'nicht',
#   'zu',
#   'flach',
#   'werden',
#   '2',
#   'Die',
#   'Form',
#   'oder',
#   'das',
#   'Blech',
#   'von',
#   'innen',
#   'einfetten',
#   'Die',
#   'Eer',
#   'den',
#   'Zucker',
#   'und',
#   'den',
#   'Vanillezucker',
#   'mit',
#   'einem',
#   'Schneebesen',
#   'schaumig',
#   'rühren',
#   'und',
#   'beiseite',
#   'stellen',
#   '3',
#   'Die',
#   'Schokolade',
#   'mit',
#   'der',
#   'Butter',
#   'bei',
#   'möglichst',
#   'geringer',
#   'Hitze',
#   'im',
#   'Wasserbad',
#   'schmelzen',
#   'Dabei',
#   'sehr',
#   'genau',
#   'darauf',
#   'achten',
#   'dass',
#   'kein',
#   'Wasser',
#   'in',
#   'die',
#   'Schokomischung',
#   'kommt',
#   'Benutzt',
#   'man',
#   'normale',
#   'Schokolade',
#   'keine',
#   'Raspelschokolade',
#   'sollte',
#   'man',
#   'sie',
#   'vorher',
#   'in',
#   'kleinere',
#   'Stücke',
#   'brechen',
#   'sonst',
#   'schmilzt',
#   'sie',
#   'nicht',
#   'so',
#   'gut',
#   '4',
#   'Die',
#   'Schokoladen',
#   'Butter',
#   'Mischung',
#   'abkühlen',
#   'lassen',
#   'sonst',
#   'flocken',
#   'die',
#   'Eier',
#   'beim',
#   'Mischen',
#   'aus',
#   '5',
#   'Die',
#   'kalte',
#   'Schokoladen',
#   'Butter',
#   'Mischung',
#   'mit',
#   'dem',
#   'Schneebesen',
#   'in',
#   'die',
#   'Ei',
#   'Zucker',
#   'Mischung',
#   'rühren',
#   'und',
#   'den',
#   'Backofen',
#   'auf',
#   '175',
#   'Grad',
#   'vorheizen',
#   '6',
#   'Die',
#   'gehackten',
#   'Walnüsse',
#   'das',
#   'Mehl',
#   'und',
#   'eine',
#   'Prise',
#   'Salz',
#   'einarbeiten',
#   'und',
#   'den',
#   'Brownieteig',
#   'in',
#   'die',
#   'Auflaufform',
#   'oder',
#   'auf',
#   'das',
#   'Blech',
#   'streichen',
#   '7',
#   'Bei',
#   '175',
#   'Grad',
#   '20',
#   '30',
#   'Minuten',
#   'backen',
#   'Dabei',
#   'ab',
#   '20',
#   'Minuten',
#   'gut',
#   'darauf',
#   'achten',
#   'die',
#   'Brownies',
#   'nicht',
#   'zu',
#   'lange',
#   'im',
#   'Ofen',
#   'zu',
#   'lassen',
#   'richtige',
#   'Brownies',
#   'sind',
#   'chewy',
#   'also',
#   'sehr',
#   'saftig',
#   'in',
#   'Norddeutschland',
#   'würde',
#   'man',
#   'vllt',
#   'sogar',
#   'klitschig',
#   'sagen',
#   'und',
#   'keinesfalls',
#   'knusprig',
#   'Die',
#   'Brownies',
#   'in',
#   'der',
#   'Form',
#   'etwas',
#   'abkühlen',
#   'lassen',
#   'und',
#   'in',
#   'Rauten',
#   'oder',
#   'Rechtecke',
#   'schneiden'],
#  ['1',
#   'Mehl',
#   'in',
#   'eine',
#   'Schüssel',
#   'sieben',
#   'in',
#   'die',
#   'Mitte',
#   'Hefe',
#   'hineinbröckeln',
#   'und',
#   'mit',
#   'Milch',
#   'verrühren',
#   'gehen',
#   'lassen2',
#   'Salz',
#   'und',
#   'Öl',
#   'zufügen',
#   'und',
#   'zu',
#   'einem',
#   'geschmeidigen',
#   'Teig',
#   'kneten',
#   'gehen',
#   'lassen',
#   '3',
#   'Zwiebel',
#   'und',
#   'Schinken',
#   'würfeln',
#   'und',
#   'in',
#   'Butter',
#   'anbraten',
#   'kurz',
#   'abkühlen',
#   'lassen4',
#   'Teig',
#   'auswellen',
#   'und',
#   'mit',
#   'Ajvar',
#   'bestreichen',
#   'Zwiebel',
#   'Schinken',
#   'Masse',
#   'darauf',
#   'verteilen5',
#   'Mit',
#   'Käse',
#   'bestreuen',
#   'und',
#   'der',
#   'Länge',
#   'nach',
#   'aufrollen',
#   '1',
#   'cm',
#   'dicke',
#   'Scheiben',
#   'abschneiden',
#   'und',
#   'auf',
#   'ein',
#   'mit',
#   'Backpapier',
#   'belegtes',
#   'Blech',
#   'geben6',
#   'Mit',
#   'Pizzagewürz',
#   'bestreuen',
#   'und',
#   'bei',
#   '200°',
#   'ca',
#   '15',
#   '20',
#   'Min',
#   'backen'],
#  ['1',
#   'Mehl',
#   'Salz',
#   'Öl',
#   'und',
#   'Wasser',
#   'zu',
#   'einem',
#   'Teig',
#   'verarbeiten',
#   'und',
#   'sehr',
#   'dünn',
#   'ausrollen',
#   '2',
#   'Crème',
#   'fraiche',
#   'mit',
#   'Salz',
#   'Pfeffer',
#   'und',
#   'Zitronensaft',
#   'glatt',
#   'rühren',
#   'und',
#   'auf',
#   'dem',
#   'Teig',
#   'verteilen',
#   '3',
#   'Zwiebeln',
#   'halbieren',
#   'in',
#   'Scheiben',
#   'schneiden',
#   'und',
#   'in',
#   'etwas',
#   'Öl',
#   'weich',
#   'dünsten',
#   'Zwiebeln',
#   'und',
#   'Schinkenwürfel',
#   'auf',
#   'dem',
#   'Fladen',
#   'verteilen',
#   '4',
#   'Flammkuchen',
#   'im',
#   'vorgeheizten',
#   'Backofen',
#   'bei',
#   '200',
#   '220°C',
#   'für',
#   'ca',
#   '10',
#   '15',
#   'Minuten',
#   'knusprig',
#   'backen'],
#  ['1',
#   'Ofen',
#   'auf',
#   '180',
#   'Grad',
#   'vorheizen',
#   'Mehl',
#   'Schokolade',
#   'Kakao',
#   'Backpulver',
#   'Zucker',
#   'Nüsse',
#   'Cappuccino',
#   'Pulver',
#   'mischen',
#   'Ei',
#   'Öl',
#   'Likör',
#   'Buttermilch',
#   'schaumig',
#   'schlagen',
#   'Mehlmischung',
#   'unterziehen',
#   '2',
#   'In',
#   'Förmchen',
#   'im',
#   'Muffinblech',
#   '25',
#   '30',
#   'Min',
#   'backen',
#   'Evtl',
#   'je',
#   '100g',
#   'helle',
#   'und',
#   'dunkle',
#   'Kuvertüre',
#   'getrennt',
#   'schmelzen',
#   'darauf',
#   'geben',
#   'und',
#   'durchziehen'],
#  ['1',
#   'Das',
#   'Olivenöl',
#   'in',
#   'eine',
#   'feuerfeste',
#   'Form',
#   'geben',
#   'Den',
#   'Knoblauch',
#   'mit',
#   'einer',
#   'feinen',
#   'Reibe',
#   'dazureiben',
#   'Salz',
#   'Pfeffer',
#   'Piment',
#   "d'Espelette",
#   'und',
#   'die',
#   'Semmelbrösel',
#   'dazugeben',
#   'und',
#   'alles',
#   'sehr',
#   'gut',
#   'vermengen',
#   '2',
#   'Nun',
#   'die',
#   'Kartoffeln',
#   'schälen',
#   'und',
#   'in',
#   'Spalten',
#   'schneiden',
#   'und',
#   'in',
#   'die',
#   'feuerfeste',
#   'Form',
#   'geben',
#   'und',
#   'gut',
#   'mit',
#   'dem',
#   'Öl',
#   'vermengen',
#   'so',
#   'dass',
#   'die',
#   'Kartoffelspalten',
#   'überall',
#   'gut',
#   'benetzt',
#   'sind',
#   'Die',
#   'Kartoffelspalten',
#   'nun',
#   'im',
#   'auf',
#   '190',
#   'Grad',
#   'vorgeheizten',
#   'Backofen',
#   'ca',
#   '50',
#   '60',
#   'goldbraun',
#   'backen'],
#  ['1',
#   'Eier',
#   'hart',
#   'kochen',
#   'abschrecken',
#   'und',
#   'abkühlen',
#   'lassen',
#   'dann',
#   'schälen',
#   'und',
#   'achteln',
#   'Nudeln',
#   'in',
#   'reichlich',
#   'Salzwasser',
#   'bissfest',
#   'kochen',
#   'und',
#   'mit',
#   'kaltem',
#   'Wasser',
#   'abschrecken',
#   'Mais',
#   'sowie',
#   'Erbsen',
#   'mit',
#   'Möhren',
#   'abtropfen',
#   'lassen',
#   'Gewürzgurken',
#   'klein',
#   'würfeln',
#   'Die',
#   'Bockwürstchen',
#   'in',
#   'Scheiben',
#   'schneiden',
#   'Petersilie',
#   'waschen',
#   'trocken',
#   'schütteln',
#   'Blätter',
#   'abzupfen',
#   'und',
#   'fein',
#   'hacken',
#   '2',
#   'Joghurt',
#   'Salatmayonnaise',
#   'Senf',
#   'Petersilie',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'in',
#   'einer',
#   'Schüssel',
#   'verrühren',
#   'Die',
#   'Salatzutaten',
#   'mit',
#   'der',
#   'Sauce',
#   'mischen',
#   'gut',
#   'durchziehen',
#   'lassen',
#   'und',
#   'vor',
#   'dem',
#   'Essen',
#   'nochmals',
#   'abschmecken',
#   '3',
#   'Tipp',
#   'Dieser',
#   'klassische',
#   'Nudelsalat',
#   'eignet',
#   'sich',
#   'prima',
#   'für',
#   'Feste',
#   'aller',
#   'Art',
#   'Hierfür',
#   'einfach',
#   'die',
#   'Zutatenmengen',
#   'entsprechend',
#   'vervielfachen',
#   '4',
#   'Weintipp',
#   'aus',
#   'dem',
#   'Buch',
#   '100',
#   'Meisterwerke',
#   'des',
#   'Weines',
#   'Deutschland',
#   '2005',
#   'Escherndorfer',
#   'Lump',
#   'Silvaner',
#   'trocken',
#   'Erste',
#   'Lage',
#   'Weingut',
#   'Juliusspital',
#   'Franken'],
#  ['1',
#   'Die',
#   '4',
#   'großen',
#   'Kartoffeln',
#   'waschen',
#   'und',
#   'überall',
#   'etwas',
#   'einstechen',
#   'Danach',
#   'auf',
#   'ein',
#   'Backblech',
#   'legen',
#   'und',
#   'im',
#   'vorgeheizten',
#   'Ofen',
#   'ca',
#   '1',
#   'Stunde',
#   'backen',
#   'E',
#   'Herd',
#   '200',
#   'Grad',
#   'Umluft',
#   '180',
#   'Grad',
#   '2',
#   'Hähnchenfilets',
#   'in',
#   'der',
#   'Hühnerbrühe',
#   'es',
#   'geht',
#   'auch',
#   'Instantbrühe',
#   'ich',
#   'mag',
#   'aber',
#   'eher',
#   'Zutaten',
#   'ohne',
#   'Stoffe',
#   'die',
#   'ich',
#   'nicht',
#   'kenne',
#   'ca',
#   '15',
#   '20',
#   'Minuten',
#   'garen',
#   '3',
#   'Hähnchenfilets',
#   'aus',
#   'der',
#   'Brühe',
#   'herausnehmen',
#   'etwas',
#   'abkühlen',
#   'lassen',
#   'und',
#   'danach',
#   'in',
#   'kleine',
#   'faserige',
#   'Stücke',
#   'zerplücken',
#   'Die',
#   'Brühe',
#   'kann',
#   'und',
#   'sollte',
#   'später',
#   'für',
#   'andere',
#   'Gerichte',
#   'wiederverwendet',
#   'werden',
#   '4',
#   'Die',
#   'Lauchzwiebeln',
#   'waschen',
#   'und',
#   'in',
#   'kleine',
#   'Ringe',
#   'schneiden',
#   'Den',
#   'Cheddarkäse',
#   'reiben',
#   'bzw',
#   'in',
#   'sehr',
#   'kleine',
#   'Würfelchen',
#   'schneiden',
#   '5',
#   'Die',
#   'Kartoffeln',
#   'abkühlen',
#   'lassen',
#   'und',
#   'Halbieren',
#   'Mit',
#   'einem',
#   'Löffel',
#   'etwas',
#   'Kartoffelmasse',
#   'aus',
#   'der',
#   'Mitte',
#   'herauskratzen',
#   'und',
#   'mit',
#   '6',
#   'Esslöffeln',
#   'Sour',
#   'Cream',
#   'vermengen',
#   '6',
#   'Auf',
#   'die',
#   'Kartoffelhälften',
#   'etwas',
#   'Worcestersauce',
#   'tröpfeln',
#   'mit',
#   'Zwiebelringen',
#   'bestreuen',
#   'und',
#   'die',
#   'Kartoffel',
#   'Cream',
#   'Masse',
#   'in',
#   'die',
#   'Kartoffeln',
#   'füllen',
#   '7',
#   'Die',
#   'Kartoffelhälften',
#   'mit',
#   'den',
#   'Hähnchenflocken',
#   'und',
#   'danach',
#   'mit',
#   'Cheddarkäse',
#   'belegen',
#   '8',
#   'Die',
#   'Kartoffelhälften',
#   'im',
#   'Backofen',
#   '20',
#   'Minuten',
#   'überbacken',
#   'Mit',
#   'den',
#   'restlichen',
#   'Lauchzwiebelringen',
#   'und',
#   'geschrotetem',
#   'Pfeffer',
#   'bestreuen',
#   'Dazu',
#   'in',
#   'einem',
#   'Schälchen',
#   'die',
#   'restliche',
#   'Sour',
#   'Cream',
#   'reichen',
#   '9',
#   'Guten',
#   'Apetit',
#   'sagt',
#   'euer',
#   'Thorsten',
#   'aus',
#   'LE'],
#  ['1',
#   'Backofen',
#   'auf',
#   '180',
#   'Grad',
#   'Umluft',
#   'vorheizen',
#   'Zwiebel',
#   'schälen',
#   'halbieren',
#   'und',
#   'in',
#   'feine',
#   'Würfel',
#   'schneiden',
#   '2',
#   'Zucchini',
#   'waschen',
#   'Möhren',
#   'mit',
#   'einem',
#   'Sparschäler',
#   'schälen',
#   'Die',
#   'Zucchini',
#   'längs',
#   'halbieren',
#   'und',
#   'in',
#   'kleine',
#   'Stücke',
#   'schneiden',
#   'Möhren',
#   'auf',
#   'einer',
#   'Küchenreibe',
#   'grob',
#   'raspeln',
#   '3',
#   'Hackfleisch',
#   'ohne',
#   'weitere',
#   'Fettzugabe',
#   'in',
#   'einer',
#   'beschichteten',
#   'Pfanne',
#   'anbraten',
#   'Wenn',
#   'das',
#   'Fleisch',
#   'rundherum',
#   'gebräunt',
#   'ist',
#   'die',
#   'Zwiebelwürfel',
#   'dazu',
#   'geben',
#   'Zwei',
#   'Minuten',
#   'mitbraten',
#   '4',
#   'Anschließend',
#   'die',
#   'Tomaten',
#   'inkl',
#   'Saft',
#   'dazugeben',
#   'und',
#   'aufkochen',
#   'Gemüse',
#   'in',
#   'die',
#   'Fleischmasse',
#   'geben',
#   'Hitze',
#   'reduzieren',
#   'und',
#   'die',
#   'Fleischmasse',
#   'einige',
#   'Minuten',
#   'köcheln',
#   'lassen',
#   '5',
#   'Die',
#   'Nudeln',
#   'ungekocht',
#   'in',
#   'eine',
#   'Auflaufform',
#   'geben',
#   'Fleisch',
#   'Gemüsemasse',
#   'mit',
#   'Milch',
#   'aufgießen',
#   'und',
#   'mit',
#   'gekörnter',
#   'Brühe',
#   'ggf',
#   'Pfeffer',
#   'und',
#   'Paprika',
#   'würzen',
#   '6',
#   'Fleisch',
#   'Gemüsemasse',
#   'über',
#   'die',
#   'Nudeln',
#   'gießen',
#   'Ca',
#   '20',
#   'Minuten',
#   'im',
#   'Ofen',
#   'garen',
#   'Währenddessen',
#   'Mozzarella',
#   'in',
#   'dünne',
#   'Scheiben',
#   'schneiden',
#   'Auflauf',
#   'mit',
#   'den',
#   'Käsescheiben',
#   'belegen',
#   'und',
#   'noch',
#   'einmal',
#   'ca',
#   '20',
#   'Minuten',
#   'backen'],
#  ['1',
#   'Kartoffeln',
#   'Möhren',
#   'und',
#   'Sellerie',
#   'schälen',
#   'und',
#   'grob',
#   'würfeln',
#   'Lauch',
#   'putzen',
#   'und',
#   'in',
#   'Ringe',
#   'schneiden',
#   '2',
#   'Öl',
#   'in',
#   'einem',
#   'Topf',
#   'erhitzen',
#   'Möhre',
#   'Sellerie',
#   'und',
#   'Lauch',
#   'darin',
#   'anbraten',
#   'Bei',
#   'geschlossenem',
#   'Deckel',
#   '5',
#   'Minuten',
#   'dünsten',
#   'lassen',
#   '3',
#   'Mit',
#   'Wasser',
#   'aufgießen',
#   'die',
#   'Brühe',
#   'hineinrühren',
#   'und',
#   'kurz',
#   'aufkochen',
#   'lassen',
#   'Dann',
#   'die',
#   'Kartoffeln',
#   'hinzugeben',
#   '10',
#   'Minuten',
#   'kochen',
#   'bis',
#   'alles',
#   'weich',
#   'ist',
#   '4',
#   'Mit',
#   'einem',
#   'Stabmixer',
#   'fein',
#   'pürieren',
#   'Mit',
#   'Majoran',
#   'Muskat',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'abschmecken',
#   '5',
#   'Kartoffelsuppe',
#   'mit',
#   'in',
#   'Scheiben',
#   'geschnittenen',
#   'Würstchen',
#   'servieren'],
#  ['1',
#   'Alle',
#   'Zutaten',
#   'für',
#   'den',
#   'Belag',
#   'in',
#   'Scheiben',
#   'schneiden',
#   '2',
#   'Den',
#   'fertigen',
#   'Pizzateig',
#   'auf',
#   'das',
#   'Waffeleisen',
#   'legen',
#   'und',
#   'mit',
#   'den',
#   'Zutaten',
#   'nach',
#   'Belieben',
#   'belegen',
#   '3',
#   'Zum',
#   'Schluss',
#   'den',
#   'Belag',
#   'mit',
#   'Pizzateig',
#   'abdecken',
#   'und',
#   'das',
#   'Waffeleisen',
#   'schließen',
#   'Die',
#   'Waffel',
#   'so',
#   'lange',
#   'backen',
#   'bis',
#   'sie',
#   'goldgelb',
#   'ausgebacken',
#   'ist',
#   'Guten',
#   'Appetit'],
#  ['1',
#   'Zwiebel',
#   'schneiden',
#   'und',
#   'Käse',
#   'grob',
#   'reiben',
#   'Die',
#   'Zwiebeln',
#   'mit',
#   'Puderzucker',
#   'und',
#   'Salz',
#   'in',
#   'Butter',
#   'glasig',
#   'werden',
#   'lassen',
#   '2',
#   'Wasser',
#   'zum',
#   'Kochen',
#   'aufsetzen',
#   '3',
#   'Für',
#   'den',
#   'Teig',
#   'Mehl',
#   'Eier',
#   'Salz',
#   'Pfeffer',
#   'Milch',
#   'und',
#   'Wasser',
#   'verquirlen',
#   'Den',
#   'Teig',
#   'durch',
#   'den',
#   'Spätzlehobel',
#   'in',
#   'kochendes',
#   'Wasser',
#   'reiben',
#   'wer',
#   'kann',
#   'schabt',
#   'natürlich',
#   'vom',
#   'Brett',
#   '4',
#   'Die',
#   'Spätzle',
#   'sind',
#   'gar',
#   'wenn',
#   'sie',
#   'oben',
#   'schwimmen',
#   'Dann',
#   'umgehend',
#   'abschöpfen',
#   '5',
#   'In',
#   'eine',
#   'Form',
#   'geben',
#   'und',
#   'einen',
#   'Teil',
#   'des',
#   'Bergkäses',
#   'und',
#   'die',
#   'glasierten',
#   'Zwiebeln',
#   'darauf',
#   'verteilen',
#   'Die',
#   'zweite',
#   'Spätzleschicht',
#   'machen',
#   'und',
#   'wieder',
#   'Käse',
#   'und',
#   'Zwiebeln',
#   'darauf',
#   'geben',
#   '6',
#   'Die',
#   'Käsespätzle',
#   'im',
#   'Backofen',
#   'bei',
#   '200',
#   'Grad',
#   'für',
#   'circa',
#   'eine',
#   'Viertelstunde',
#   'backen'],
#  ['1',
#   'Wichtig',
#   'Den',
#   'Salat',
#   'einen',
#   'Tag',
#   'vorher',
#   'zubereiten',
#   'und',
#   'kühl',
#   'stellen',
#   'damit',
#   'er',
#   'durchziehen',
#   'kann',
#   '2',
#   'Selleriesalat',
#   'abtropfen',
#   'lassen',
#   'Äpfel',
#   'entkernen',
#   'und',
#   'würfeln',
#   'Schinken',
#   'würfeln',
#   'Porree',
#   'in',
#   'feine',
#   'Ringe',
#   'schneiden',
#   'Eisbergsalat',
#   'waschen',
#   'und',
#   'in',
#   'Streifen',
#   'schneiden',
#   'Ananas',
#   'würfeln',
#   'Eier',
#   'in',
#   'einem',
#   'Topf',
#   'Wasser',
#   'ca',
#   '12',
#   '15',
#   'Minuten',
#   'hart',
#   'kochen',
#   'abkühlen',
#   'lassen',
#   'und',
#   'würfeln',
#   '3',
#   'Alle',
#   'Zutaten',
#   'in',
#   'dieser',
#   'Reihenfolge',
#   'in',
#   'einer',
#   'großen',
#   'Schüssel',
#   'am',
#   'schönsten',
#   'in',
#   'einer',
#   'Glasschüssel',
#   'schichten',
#   'Sellerie',
#   'Äpfel',
#   'Schinken',
#   'Porree',
#   'Eisbergsalat',
#   'Mais',
#   'Ananas',
#   'Eier',
#   'dann',
#   'mit',
#   'Miracel',
#   'Whip',
#   'bedecken',
#   'und',
#   'Käse',
#   'darüber',
#   'streuen',
#   '4',
#   'Der',
#   'Salat',
#   'kann',
#   'vor',
#   'dem',
#   'Servieren',
#   'gemischt',
#   'werden',
#   'schöner',
#   'sieht',
#   'es',
#   'aber',
#   'aus',
#   'wenn',
#   'man',
#   'die',
#   'Schichten',
#   'so',
#   'lässt'],
#  ['Den',
#   'Rhabarber',
#   'schälen',
#   'in',
#   'kleine',
#   'Stücke',
#   'schneiden',
#   'und',
#   'zuckern',
#   'Etwa',
#   'eine',
#   'halbe',
#   'Stunde',
#   'ziehen',
#   'lassen',
#   'Danach',
#   'in',
#   'einem',
#   'Sieb',
#   'gut',
#   'abtropfen',
#   'lassen',
#   'In',
#   'der',
#   'Zwischenzeit',
#   'aus',
#   'den',
#   'Zutaten',
#   'für',
#   'den',
#   'Teig',
#   'einen',
#   'Rührteig',
#   'herstellen',
#   'und',
#   'in',
#   'eine',
#   'gefettete',
#   'Springform',
#   '28',
#   'cm',
#   'Durchmesser',
#   'füllen',
#   'Bei',
#   '180°',
#   'im',
#   'vorgeheizten',
#   'Backofen',
#   'ca',
#   '15',
#   'Minuten',
#   'vorbacken',
#   'Für',
#   'die',
#   'Streusel',
#   'Mehl',
#   'Zucker',
#   'Vanillezucker',
#   'und',
#   'Zimt',
#   'mit',
#   'der',
#   'Butter',
#   'zu',
#   'einer',
#   'krümeligen',
#   'Masse',
#   'verkneten',
#   'Für',
#   'die',
#   'Creme',
#   'Den',
#   'Pudding',
#   'mit',
#   'dem',
#   'Zucker',
#   'und',
#   'der',
#   'Milch',
#   'kochen',
#   'und',
#   'unter',
#   'ständigem',
#   'Rühren',
#   'etwas',
#   'abkühlen',
#   'lassen',
#   'Den',
#   'Schmand',
#   'unterrühren',
#   'und',
#   'auf',
#   'dem',
#   'Kuchenboden',
#   'verteilen',
#   'Darüber',
#   'die',
#   'Rhabarberstücke',
#   'verteilen',
#   'und',
#   'die',
#   'Streusel',
#   'darüber',
#   'streuen',
#   'Den',
#   'Kuchen',
#   'bei',
#   '180°',
#   'ca',
#   '30',
#   '35',
#   'Minuten',
#   'fertig',
#   'backen',
#   'lassen',
#   'In',
#   'der',
#   'Form',
#   'auskühlen',
#   'lassen',
#   'und',
#   'mit',
#   'Puderzucker',
#   'bestreuen',
#   'Tipp',
#   'Wenn',
#   'man',
#   'den',
#   'Kuchen',
#   'nach',
#   'dem',
#   'Backen',
#   'kühllagert',
#   'wird',
#   'die',
#   'Puddingcreme',
#   'feste',
#   'dann',
#   'schmeckt',
#   'er',
#   'noch',
#   'besser',
#   'und',
#   'man',
#   'kann',
#   'ihn',
#   'leichter',
#   'schneiden',
#   'Viel',
#   'Spaß',
#   'beim',
#   'nachbacken'],
#  ['1',
#   'Gesalzenes',
#   'Wasser',
#   'zum',
#   'Kochen',
#   'bringen',
#   'Die',
#   'Reisnudeln',
#   'darin',
#   '12',
#   'Minuten',
#   'kochen',
#   'In',
#   'ein',
#   'Sieb',
#   'abschütten',
#   'und',
#   'abkühlen',
#   'lassen',
#   'Dabei',
#   'mehrmals',
#   'umrühren',
#   'Die',
#   'lauwarmen',
#   'Reisnudeln',
#   'in',
#   'eine',
#   'Schüssel',
#   'umfüllen',
#   'Die',
#   'getrockneten',
#   'Tomaten',
#   'in',
#   'sehr',
#   'feinen',
#   'Streifen',
#   'schneiden',
#   'und',
#   'dazu',
#   'geben',
#   '2',
#   'Den',
#   'Feta',
#   'in',
#   'kleine',
#   'Würfel',
#   'schneiden',
#   'Rucola',
#   'mit',
#   'einer',
#   'Schere',
#   'in',
#   'feine',
#   'Streifen',
#   'schneiden',
#   'und',
#   'beides',
#   'beiseite',
#   'stellen',
#   '3',
#   'Nun',
#   'Olivenöl',
#   'Balsamico',
#   'Essig',
#   'italienische',
#   'Salatkräuter',
#   'und',
#   'Wasser',
#   'zu',
#   'den',
#   'Reisnudeln',
#   'abgeben',
#   'und',
#   'gut',
#   'vermengen',
#   'Statt',
#   'italienischen',
#   'Kräutern',
#   'gerne',
#   'auch',
#   'Kräutermischung',
#   'aus',
#   'eigener',
#   'Herstellung',
#   'verwenden',
#   'siehe',
#   'Rezept',
#   'Diverses',
#   'SALAT',
#   'KRÄUTER',
#   'MISCHUNG4',
#   'Jetzt',
#   'die',
#   'Feta',
#   'Würfel',
#   'vorsichtig',
#   'unterheben',
#   'Den',
#   'Salat',
#   'für',
#   'eine',
#   'Stunde',
#   'durchziehen',
#   'lassen',
#   'Vor',
#   'dem',
#   'Servieren',
#   'die',
#   'Rucola',
#   'Streifen',
#   'unterheben'],
#  ['1',
#   'Eiweiß',
#   'und',
#   'Eigelb',
#   'in',
#   'zwei',
#   'Schüsseln',
#   'groß',
#   'und',
#   'klein',
#   'trennen',
#   'Eiweiß',
#   'in',
#   'die',
#   'große',
#   'Schüssel',
#   'geben',
#   'und',
#   'in',
#   'den',
#   'Kühlschrank',
#   'stellen',
#   '2',
#   'Ofen',
#   'auf',
#   '170',
#   'Grad',
#   'vorheizen',
#   '3',
#   'Schokolade',
#   'in',
#   'eine',
#   'große',
#   'Schüssel',
#   'geben',
#   'und',
#   'über',
#   'dem',
#   'Wasserbad',
#   'schmelzen',
#   'Dabei',
#   'cremig',
#   'rühren',
#   '4',
#   'Eiweiß',
#   'mit',
#   'dem',
#   'Mixer',
#   'steif',
#   'schlagen',
#   '5',
#   'Wenn',
#   'die',
#   'Schokolade',
#   'abgekühlt',
#   'ist',
#   'erst',
#   'die',
#   'drei',
#   'Eigelbe',
#   'dann',
#   'mit',
#   'einem',
#   'Schneebesen',
#   'ein',
#   'Drittel',
#   'des',
#   'Eischnees',
#   'unterrühren',
#   'Den',
#   'Rest',
#   'des',
#   'Eischnees',
#   'in',
#   'zwei',
#   'Schritten',
#   'mit',
#   'einem',
#   'Spatel',
#   'unterheben',
#   '6',
#   'Backform',
#   'mit',
#   'Backpapier',
#   'auslegen',
#   'und',
#   'die',
#   'Masse',
#   'einfüllen',
#   'Form',
#   'leicht',
#   'schütteln',
#   'damit',
#   'sich',
#   'keine',
#   'Luftblasen',
#   'bilden',
#   'Bei',
#   '170',
#   'Grad',
#   '30',
#   '40',
#   'Minuten',
#   'backen',
#   '7',
#   'In',
#   'der',
#   'Form',
#   'abkühlen',
#   'lassen',
#   'und',
#   'anschließend',
#   'ohne',
#   'Form',
#   'auf',
#   'einem',
#   'Kuchenrost',
#   'auskühlen',
#   'lassen',
#   '8',
#   'Mit',
#   'Puderzucker',
#   'verzieren',
#   'Fertig'],
#  ['Minzblätter',
#   'in',
#   'ein',
#   'bauchiges',
#   'Weinglas',
#   'geben',
#   'Die',
#   'Blätter',
#   'mit',
#   'dem',
#   'Mörser',
#   'etwas',
#   'andrücken',
#   'Eine',
#   'Limettenscheibe',
#   'und',
#   'Eiswürfel',
#   'dazu',
#   'Dann',
#   'mit',
#   'Prosecco',
#   'Mineralwasser',
#   'und',
#   'Holunderblütensirup',
#   'auffüllen',
#   'Fertig',
#   'und',
#   'genießen'],
#  ['1',
#   'Ofen',
#   'auf',
#   '180ºC',
#   'vorheizen',
#   '2',
#   'Backblech',
#   'mit',
#   'Öl',
#   'ausstreichen',
#   '3',
#   'Mozzarella',
#   'in',
#   'dünne',
#   'Scheiben',
#   'schneiden',
#   'und',
#   'Backblech',
#   'dicht',
#   'auslegen',
#   'Restlichen',
#   'Käse',
#   'für',
#   'Belag',
#   'aufheben',
#   '4',
#   'Frischkäse',
#   'Sahne',
#   'Eier',
#   'Parmesan',
#   'und',
#   'Knoblauch',
#   'vermengen',
#   '5',
#   'Masse',
#   'über',
#   'den',
#   'Mozzarella',
#   'giessen',
#   'und',
#   'alles',
#   '30',
#   'Min',
#   'auf',
#   'der',
#   'tiefsten',
#   'Stufe',
#   'backen',
#   '6',
#   'Aus',
#   'dem',
#   'Ofen',
#   'nehmen',
#   'mit',
#   'Pizzasauce',
#   'und',
#   'gewünschten',
#   'Zutaten',
#   'belegen',
#   '7',
#   'Weiter',
#   '10',
#   '15',
#   'Minuten',
#   'backen',
#   'bis',
#   'die',
#   'Pizza',
#   'knusprig',
#   'ist',
#   '8',
#   'Finde',
#   'weitere',
#   'Rezepte',
#   'auf',
#   'www',
#   'proteinrezepte',
#   'com'],
#  ['Aus',
#   'Mehl',
#   'Eiern',
#   'Salz',
#   'und',
#   'Backpulver',
#   'einen',
#   'Teig',
#   'herstellen',
#   'Falls',
#   'er',
#   'zu',
#   'dick',
#   'ist',
#   'etwas',
#   'Wasser',
#   'zugeben',
#   'Die',
#   'Bananen',
#   'pellen',
#   'jede',
#   '2x',
#   'durchschneiden',
#   'und',
#   'in',
#   'den',
#   'Backteig',
#   'geben',
#   'Das',
#   'Öl',
#   'erhitzen',
#   'und',
#   'die',
#   'Bananen',
#   'goldgelb',
#   'ausbacken',
#   'Auf',
#   'einem',
#   'Küchentuch',
#   'kurz',
#   'abtropfen',
#   'lassen',
#   'Auf',
#   'Dessertteller',
#   'geben',
#   'und',
#   'nach',
#   'Geschmack',
#   'mit',
#   'Honig',
#   'überziehen',
#   'Dazu',
#   'passt',
#   'auch',
#   'super',
#   'Vanilleeis',
#   'Statt',
#   'Bananen',
#   'kann',
#   'man',
#   'auch',
#   'Ananas',
#   'verwenden'],
#  ['1',
#   'Butter',
#   'Zucker',
#   'und',
#   'Gewürze',
#   'mit',
#   'dem',
#   'Eigelb',
#   'glatt',
#   'arbeiten',
#   'Mehl',
#   'mit',
#   'dem',
#   'Backpulver',
#   'mischen',
#   'unter',
#   'die',
#   'Buttermasse',
#   'kneten',
#   'und',
#   'alles',
#   'zügig',
#   'zu',
#   'einem',
#   'glatten',
#   'Teig',
#   'verarbeiten',
#   'Den',
#   'Teig',
#   'für',
#   'rund',
#   'eine',
#   'Stunde',
#   'in',
#   'den',
#   'Kühlschrank',
#   'stellen',
#   'Anschließend',
#   'den',
#   'Teig',
#   'ausrollen',
#   'und',
#   'den',
#   'gefetteten',
#   'Boden',
#   'einer',
#   'Springform',
#   'Ø',
#   '26',
#   '28',
#   'cm',
#   'damit',
#   'auslegen',
#   '2',
#   'Schichtkäse',
#   'saure',
#   'Sahne',
#   'Gewürze',
#   'Eigelb',
#   'Puddingpulver',
#   'und',
#   'Milch',
#   'glatt',
#   'rühren',
#   'Eiweiß',
#   'und',
#   'Zucker',
#   'zu',
#   'einem',
#   'cremigen',
#   'Eischnee',
#   'aufschlagen',
#   'Den',
#   'Eischnee',
#   'unter',
#   'die',
#   'Käsemasse',
#   'heben',
#   'Die',
#   'Masse',
#   'in',
#   'die',
#   'Springform',
#   'mit',
#   'dem',
#   'Mürbeteigboden',
#   'einfüllen',
#   'Den',
#   'Kuchen',
#   'im',
#   'auf',
#   '200°C',
#   'vorgeheizten',
#   'Backofen',
#   'bei',
#   'Ober',
#   'und',
#   'Unterhitze',
#   'auf',
#   'mittlerer',
#   'Schiene',
#   'ca',
#   '10',
#   '15',
#   'Min',
#   'anbacken',
#   '3',
#   'Die',
#   'Form',
#   'aus',
#   'dem',
#   'Backofen',
#   'herausnehmen',
#   'und',
#   'den',
#   'angebackenen',
#   'Kuchenrand',
#   'mit',
#   'einem',
#   'Messer',
#   'rundherum',
#   'leicht',
#   'einschneiden',
#   'Die',
#   'Temperatur',
#   'des',
#   'Backofens',
#   'auf',
#   '160°C',
#   'herunterstellen',
#   '4',
#   'Nach',
#   '10',
#   'Minuten',
#   'den',
#   'Kuchen',
#   'wieder',
#   'in',
#   'den',
#   'Backofen',
#   'stellen',
#   'und',
#   'nochmals',
#   'ca',
#   '50',
#   'Minuten',
#   'weiter',
#   'backen',
#   'Nach',
#   'dem',
#   'Auskühlen',
#   'den',
#   'Kuchen',
#   'aus',
#   'der',
#   'Springform',
#   'nehmen',
#   'und',
#   'leicht',
#   'mit',
#   'Puderzucker',
#   'bestreuen'],
#  ['1',
#   'Olivenöl',
#   'in',
#   'einer',
#   'Pfanne',
#   'erhitzen',
#   'Das',
#   'Hackfleisch',
#   'darin',
#   'gut',
#   'anbraten',
#   'und',
#   'großzügig',
#   'salzen',
#   'und',
#   'pfeffern',
#   'Zwiebel',
#   'Knoblauch',
#   'und',
#   'Suppengrün',
#   'klein',
#   'schneiden',
#   'und',
#   'dazu',
#   'geben',
#   '2',
#   'Mit',
#   'passierten',
#   'Tomaten',
#   'die',
#   'Soße',
#   'verflüssigen',
#   'und',
#   'wenn',
#   'nötig',
#   'mit',
#   'Wasser',
#   'verlängern',
#   '3',
#   'Die',
#   'Lasagneblätter',
#   'in',
#   'die',
#   'Soße',
#   'reinlegen',
#   'Eine',
#   'Schicht',
#   'Ricotta',
#   'darauf',
#   'verteilen',
#   'und',
#   'mit',
#   'geriebenem',
#   'Mozzarella',
#   'abschließen',
#   'Die',
#   'Lasagne',
#   'im',
#   'Backofen',
#   '25',
#   'Minuten',
#   'lang',
#   'bei',
#   '180°',
#   'backen',
#   'Mit',
#   'frischen',
#   'Basilikum',
#   'servieren'],
#  ['1',
#   'Den',
#   'Blätterteig',
#   'aufrollen',
#   'und',
#   'jede',
#   'Rolle',
#   'in',
#   'sechs',
#   'Qadrate',
#   'schneiden',
#   'Diese',
#   'auf',
#   'zwei',
#   'mit',
#   'Backpapier',
#   'ausgelegte',
#   'Backbleche',
#   'legen',
#   'Die',
#   'restlichen',
#   'Zutaten',
#   'miteinander',
#   'gut',
#   'verrühren',
#   'und',
#   'die',
#   'Masse',
#   'auf',
#   'die',
#   'Quadrate',
# ...
#   'Champignons',
#   'putzen',
#   'und',
#   'in',
#   'Scheiben',
#   'schneiden',
#   'Zwiebel',
#   'von',
#   'der',
#   'Haut',
#   'befreien',
#   'halbieren',
#   'und',
#   'in',
#   'Streifen',
#   'schneiden',
#   'Das',
#   'Öl',
#   'in',
#   'einer',
#   'Pfanne',
#   'erhitzen',
#   'Champignons',
#   'und',
#   'Zwiebeln',
#   'darin',
#   'anbraten',
#   'mit',
#   'der',
#   'Sahne',
#   'ablöschen',
#   'und',
#   'etwas',
#   'einkochen',
#   'lassen',
#   'salzen',
#   'pfeffern',
#   'und',
#   'beiseite',
#   'stellen',
#   '4',
#   'Die',
#   'Hälfte',
#   'des',
#   'Spätzleteiges',
#   'mit',
#   'einer',
#   'Presse',
#   'ins',
#   'Wasser',
#   'drücken',
#   'warten',
#   'bis',
#   'sie',
#   'an',
#   'die',
#   'Oberfläche',
#   'kommen',
#   'und',
#   'dann',
#   'herausschöpfen',
#   'In',
#   'eine',
#   'Schüssel',
#   'geben',
#   'mit',
#   'lauwarmem',
#   'Wasser',
#   'und',
#   'kurz',
#   'durchschwenken',
#   'herausnehmen',
#   'abtropfen',
#   'lassen',
#   'und',
#   'in',
#   'die',
#   'Auflaufschüssel',
#   'geben',
#   '5',
#   'Spätzle',
#   'mit',
#   'der',
#   'Champignon',
#   'Zwiebelmasse',
#   'belegen',
#   '6',
#   'Restlichen',
#   'Teig',
#   'wie',
#   'vorhin',
#   'verarbeiten',
#   'und',
#   'die',
#   'Spätzle',
#   'auf',
#   'der',
#   'Champignonmasse',
#   'verteilen',
#   'Den',
#   'geriebenen',
#   'Käse',
#   'auf',
#   'die',
#   'Spätzle',
#   'verteilen',
#   'und',
#   'mit',
#   'ein',
#   'paar',
#   'Butterflöckchen',
#   'belegen',
#   'Im',
#   'Backofen',
#   'bei',
#   '180°',
#   'C',
#   'überbacken',
#   'bis',
#   'die',
#   'Oberfläche',
#   'leicht',
#   'braun',
#   'wird'],
#  ['1',
#   'Außer',
#   'Puderzucker',
#   'und',
#   'Vanillezucker',
#   'wird',
#   'erst',
#   'nach',
#   'dem',
#   'Backen',
#   'gebraucht',
#   'alle',
#   'Zutaten',
#   'zu',
#   'einem',
#   'Teig',
#   'verkneten',
#   'Aus',
#   'dem',
#   'Teig',
#   'eine',
#   'ca',
#   '2',
#   'cm',
#   'dicke',
#   'Rolle',
#   'formen',
#   'und',
#   'je',
#   'etwa',
#   '1',
#   'cm',
#   'dicke',
#   'Stücke',
#   'abschneiden',
#   'Die',
#   'einzelen',
#   'Teigstücke',
#   'dann',
#   'wieder',
#   'zu',
#   'kleinen',
#   'Rollen',
#   'formen',
#   'und',
#   'im',
#   'Halbbogen',
#   'Kipferlform',
#   'auf',
#   'ein',
#   'mit',
#   'Backpapier',
#   'ausgelegtes',
#   'Blech',
#   'legen',
#   'Im',
#   'vorgeheizten',
#   'Backofen',
#   'bei',
#   '180',
#   'Gras',
#   'ca',
#   '12',
#   'Minuten',
#   'backen',
#   '2',
#   'Nach',
#   'dem',
#   'Backen',
#   'die',
#   'Plätzchen',
#   'auskühlen',
#   'lassen',
#   'Puder',
#   'und',
#   'Vanillezucker',
#   'mischen',
#   'und',
#   'die',
#   'Kipferl',
#   'damit',
#   'besteuben',
#   '3',
#   'Ofentemperatur',
#   '180',
#   'Grad',
#   'Backzeit',
#   'ca',
#   '12',
#   'Minuten',
#   'Man',
#   'kann',
#   'zum',
#   'Backen',
#   'natürlich',
#   'auch',
#   'Margarine',
#   'nehmen',
#   'dann',
#   'reduzieren',
#   'sich',
#   'zwar',
#   'die',
#   'Kalorien',
#   'aber',
#   'meiner',
#   'Meinung',
#   'auch',
#   'der',
#   'Geschmack'],
#  ['1',
#   'Eier',
#   'mit',
#   'Zucker',
#   'dickcremig',
#   'schlagen',
#   'Mehl',
#   'Backpulver',
#   'und',
#   'Speisestärke',
#   'vorsichtig',
#   'unterschlagen',
#   'und',
#   'die',
#   'zerlassene',
#   'abgekühlte',
#   'margarine',
#   'tropfenweise',
#   'unterheben',
#   'Auf',
#   'einem',
#   'mit',
#   'Backpapier',
#   'ausgelegten',
#   'Blech',
#   'backen',
#   'Die',
#   'abgekühlte',
#   'Unterseite',
#   'des',
#   'Bodens',
#   'mit',
#   'in',
#   'Öl',
#   'zerlassener',
#   'und',
#   'gut',
#   'verrührter',
#   'Schokolade',
#   'bestreichen',
#   'und',
#   'festwerden',
#   'lassen',
#   '2',
#   'Aus',
#   'Milch',
#   'Puddingpulver',
#   'und',
#   'Zucker',
#   'einen',
#   'ganz',
#   'straffen',
#   'Pudding',
#   'kochen',
#   'und',
#   'sofort',
#   'mit',
#   'in',
#   '100',
#   'ml',
#   'heißen',
#   'Likör',
#   'aufgelöster',
#   'Götterspeise',
#   'verrühren',
#   'Auch',
#   'das',
#   'Hartfett',
#   'einrühren',
#   'Den',
#   'übrigen',
#   'Likör',
#   'in',
#   'den',
#   'noch',
#   'warmen',
#   'Pudding',
#   'rühren',
#   'Butter',
#   'und',
#   'Margarine',
#   'cremig',
#   'schlagen',
#   'und',
#   'den',
#   'handwarmen',
#   'Pudding',
#   'löffelweise',
#   'unterschlagen',
#   'Creme',
#   'auf',
#   'die',
#   'fest',
#   'gewordene',
#   'Schokolade',
#   'streichen',
#   'Mit',
#   'kamm',
#   'oder',
#   'Gabel',
#   'garnieren',
#   'und',
#   'mit',
#   'Schokoraspeln',
#   'bestreuen',
#   '3',
#   'Für',
#   'die',
#   'Kinder',
#   'Variante',
#   'wird',
#   'der',
#   'Pfefferminzlikör',
#   'durch',
#   'Waldmeistersaft',
#   'ersetzt',
#   '4',
#   'Backzeit',
#   '10',
#   '15',
#   'Minuten',
#   'bei',
#   '180',
#   '200°C'],
#  ['1',
#   'Die',
#   'Ente',
#   'auftauen',
#   'waschen',
#   'und',
#   'mit',
#   'einem',
#   'Küchentuch',
#   'trockentupfen',
#   'Dann',
#   'innen',
#   'und',
#   'außen',
#   'einsalzen',
#   'und',
#   'über',
#   'Nacht',
#   'am',
#   'besten',
#   'im',
#   'Kühlschrank',
#   'stehen',
#   'lassen',
#   'damit',
#   'das',
#   'Salz',
#   'gut',
#   'einziehen',
#   'kann',
#   'Am',
#   'nächsten',
#   'Tag',
#   'das',
#   'nicht',
#   'eingezogene',
#   'Salz',
#   'abwaschen',
#   'und',
#   'wiederrum',
#   'die',
#   'Ente',
#   'trocken',
#   'tupfen',
#   '2',
#   'Die',
#   'Orange',
#   'und',
#   'die',
#   'Grapefruit',
#   'so',
#   'mit',
#   'einem',
#   'Messer',
#   'schälen',
#   'dass',
#   'das',
#   'Weiße',
#   'mit',
#   'entfernt',
#   'ist',
#   'Dann',
#   'in',
#   'Würfel',
#   'schneiden',
#   'Den',
#   'Boskop',
#   'schälen',
#   'und',
#   'entkernen',
#   'und',
#   'auch',
#   'in',
#   'würfl',
#   'schneiden',
#   'Alles',
#   'in',
#   'ene',
#   'Schüssel',
#   'geben',
#   'und',
#   'die',
#   'Petersilie',
#   'darübergeben',
#   'und',
#   'durchmengen',
#   'Die',
#   'Ente',
#   'von',
#   'hinten',
#   'und',
#   'von',
#   'vorne',
#   'mit',
#   'der',
#   'Füllung',
#   'bestücken',
#   'die',
#   'Öffnungen',
#   'mit',
#   'einem',
#   'Spießchen',
#   'verschließen',
#   '3',
#   'Nun',
#   'die',
#   'Ente',
#   'etwas',
#   'mit',
#   'Pfeffer',
#   'bestreuen',
#   'und',
#   'leicht',
#   'einreiben',
#   'Den',
#   'Backofen',
#   'auf',
#   '190',
#   'Grad',
#   'vorheizen',
#   'und',
#   'die',
#   'Ente',
#   'auf',
#   'eine',
#   'Grillschale',
#   'mit',
#   'Grillgitter',
#   'legen',
#   'damit',
#   'sie',
#   'nicht',
#   'im',
#   'Fond',
#   'schwimmt',
#   'und',
#   'auch',
#   'die',
#   'untere',
#   'Seite',
#   'knusprig',
#   'wird',
#   'und',
#   'auf',
#   'der',
#   'unteren',
#   'Schiene',
#   'in',
#   'den',
#   'Backofen',
#   'stellen',
#   'Nach',
#   '10',
#   'Min',
#   'die',
#   'Ente',
#   'das',
#   'erste',
#   'mal',
#   'mit',
#   'dem',
#   'Malzbier',
#   'bepinseln',
#   'Dieses',
#   'oft',
#   'wiederholen',
#   'und',
#   'zum',
#   'Schluß',
#   'den',
#   'Rest',
#   'des',
#   'Malzbieres',
#   'über',
#   'die',
#   'Ente',
#   'verteilen',
#   'zwischendurch',
#   'sie',
#   'auch4',
#   'Die',
#   'Garzeit',
#   'war',
#   '2',
#   'Stunden',
#   'Habe',
#   'sie',
#   'in',
#   'der',
#   'Zeit',
#   'zweimal',
#   'gewendet',
#   'Dann',
#   'die',
#   'Ente',
#   'herausnehmen',
#   'und',
#   'auf',
#   'eine',
#   'Platte',
#   'legen',
#   'den',
#   'Backofen',
#   'ausschalten',
#   'und',
#   'die',
#   'Ente',
#   'darin',
#   'warmstellen',
#   '5',
#   'Für',
#   'die',
#   'Sauce',
#   'habe',
#   'ich',
#   'den',
#   'Fond',
#   'genommen',
#   'und',
#   'noch',
#   'etwas',
#   'kaltes',
#   'Wasser',
#   'dazu',
#   'gegeben',
#   'bis',
#   'es',
#   '500ml',
#   'waren',
#   'Dadurch',
#   'konnte',
#   'ich',
#   'das',
#   'Fett',
#   'gut',
#   'abschöpfen',
#   'Den',
#   'Fond',
#   'mit',
#   'dem',
#   'Sherry',
#   'aufkochen',
#   'und',
#   'mit',
#   'der',
#   'in',
#   'kaltem',
#   'Wasser',
#   'aufgelösten',
#   'Speisestärke',
#   'gebunden',
#   'Evtl',
#   'noch',
#   'mit',
#   'etwas',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'abschmecken'],
#  ['1',
#   'Die',
#   'Kartoffeln',
#   'schälen',
#   'waschen',
#   'und',
#   'klein',
#   'schneiden',
#   'Porree',
#   'säubern',
#   'und',
#   'in',
#   'feine',
#   'Ringe',
#   'schneiden',
#   'Das',
#   'Gemüse',
#   'in',
#   '0',
#   '5',
#   'Liter',
#   'Gemüse',
#   'oder',
#   'Fleischbrühe',
#   'zugedeckt',
#   'etwa',
#   '20',
#   'Minuten',
#   'köcheln',
#   'lassen',
#   '2',
#   'Währenddessen',
#   'Petersilie',
#   'waschen',
#   'trockentupfen',
#   'die',
#   'Blättchen',
#   'auszupfen',
#   'und',
#   'bis',
#   'auf',
#   'einige',
#   'zum',
#   'garnieren',
#   'fein',
#   'hacken',
#   'Chilischote',
#   'längs',
#   'einschneiden',
#   'entkernen',
#   'und',
#   'sehr',
#   'fein',
#   'schneiden',
#   '3',
#   'Das',
#   'Hackfleisch',
#   'mit',
#   'dem',
#   'Eigelb',
#   'Chili',
#   'Semmelbrösel',
#   'Paniermehl',
#   'Salz',
#   'Pfeffer',
#   'und',
#   'etwas',
#   'Petersilie',
#   'gut',
#   'vermengen',
#   'Alles',
#   'gut',
#   'durchkneten',
#   'das',
#   'funktioniert',
#   'gut',
#   'mit',
#   'den',
#   'Händen',
#   '4',
#   'Aus',
#   'der',
#   'Hackmasse',
#   'mit',
#   'angefeuchteten',
#   'Händen',
#   'kleine',
#   'Bällchen',
#   'mit',
#   'ca',
#   '2',
#   'cm',
#   'Durchmesser',
#   'formen',
#   'Olivenöl',
#   'in',
#   'einer',
#   'Pfanne',
#   'erhitzen',
#   'die',
#   'Hackbällchen',
#   'rundherum',
#   'unter',
#   'Wenden',
#   '4',
#   '5',
#   'Minuten',
#   'braten',
#   '5',
#   'Aus',
#   'der',
#   'Suppe',
#   '2',
#   '3',
#   'EL',
#   'Gemüsestücke',
#   'herausheben',
#   'Restliches',
#   'Gemüse',
#   'in',
#   'der',
#   'Brühe',
#   'mit',
#   'einem',
#   'Stabmixer',
#   'pürieren',
#   'Die',
#   'Suppe',
#   'mit',
#   'Sahne',
#   'verfeinern',
#   'und',
#   'mit',
#   'Salz',
#   'Pfeffer',
#   'und',
#   'Muskatnuss',
#   'abschmecken',
#   'Gemüsestücke',
#   'und',
#   'Hackbällchen',
#   'in',
#   'die',
#   'Suppe',
#   'geben',
#   'eventuell',
#   'noch',
#   'mal',
#   'erwärmen',
#   'Mit',
#   'Petersilie',
#   'garniert',
#   'servieren',
#   'Tipps',
#   '6',
#   'Die',
#   'Hackmasse',
#   'darf',
#   'nicht',
#   'zu',
#   'wenig',
#   'gesalzen',
#   'und',
#   'gewürzt',
#   'sein',
#   'weil',
#   'sie',
#   'dann',
#   'als',
#   'fertige',
#   'Hackbällchen',
#   'fade',
#   'schmeckt',
#   '7',
#   '1',
#   '2',
#   'Spritzer',
#   'Zitronensaft',
#   'in',
#   'die',
#   'Porree',
#   'Kartoffelsuppe',
#   'gibt',
#   'noch',
#   'einen',
#   'extra',
#   'Kick',
#   'Viel',
#   'Freude',
#   'und',
#   'guten',
#   'Appetit'],
#  ['1',
#   'Gemüse',
#   'putzen',
#   'schälen',
#   'und',
#   'raspeln',
#   '2',
#   'In',
#   'einer',
#   'Pfanne',
#   'anschwitzen',
#   'und',
#   'mit',
#   'Gemüsebrühe',
#   'ablöschen',
#   'Knobi',
#   'dazugeben',
#   'Mit',
#   'Pfeffer',
#   'Salz',
#   'und',
#   'Muskatnuss',
#   'würzen',
#   'Aus',
#   'der',
#   'Pfanne',
#   'nehmen',
#   'etwas',
#   'abkühlen',
#   'und',
#   'saure',
#   'Sahne',
#   'dazurühren',
#   'Backofen',
#   'auf',
#   '200',
#   'Grad',
#   'vorheizen',
#   '3',
#   'Tomaten',
#   'waschen',
#   'putzen',
#   'und',
#   'würfeln',
#   'In',
#   'einer',
#   'heißen',
#   'Pfanne',
#   'ohne',
#   'Öl',
#   'kurz',
#   'anrösten',
#   'und',
#   'mit',
#   'Gemüsebrühe',
#   'ablöschen',
#   'Tomatenmark',
#   'unterrühren',
#   'Mit',
#   'Salz',
#   'Pfeffer',
#   'Knobipfeffer',
#   'und',
#   'mit',
#   'frische',
#   'Kräuter',
#   'würzen',
#   'und',
#   'in',
#   'eine',
#   'Auflaufform',
#   'geben',
#   '4',
#   'Gemüsefüllung',
#   'in',
#   'den',
#   'Putenschinken',
#   'rollen',
#   'Die',
#   'Rollen',
#   'mit',
#   'der',
#   'Öffnung',
#   'nach',
#   'unten',
#   'auf',
#   'die',
#   'Tomatensoße',
#   'setzen',
#   'Mit',
#   'Käse',
#   'bestreuen',
#   'und',
#   'im',
#   'Ofen',
#   'ca',
#   '20',
#   'Minuten',
#   'backen',
#   '5',
#   'Servieren'],
#  ['1',
#   'Die',
#   'sehr',
#   'fein',
#   'gewürfelten',
#   'Zwiebeln',
#   'in',
#   'der',
#   'Butter',
#   'in',
#   'einer',
#   'Pfanne',
#   'bräunen',
#   'lassen',
#   '2',
#   'Brühe',
#   'und',
#   'Sahne',
#   'vermischen',
#   'und',
#   'die',
#   'Semmelbrösel',
#   'darin',
#   'gut',
#   '10',
#   'Minuten',
#   'quellen',
#   'lassen',
#   '3',
#   'Alle',
#   'Zutaten',
#   'zum',
#   'Hack',
#   'geben',
#   'zuletzt',
#   'die',
#   'angebräunten',
#   'Zwiebeln',
#   'mit',
#   'dem',
#   'Bratfett',
#   'und',
#   'die',
#   'eingeweichten',
#   'Semmelbrösel',
#   'Alles',
#   'gut',
#   'vermengen',
#   '4',
#   'Mit',
#   'feuchten',
#   'Händen',
#   'kleine',
#   'Bällchen',
#   'formen',
#   'und',
#   'diese',
#   'nach',
#   'und',
#   'nach',
#   'in',
#   'Öl',
#   'oder',
#   'Butterschmalz',
#   'von',
#   'allen',
#   'Seiten',
#   'braten',
#   'Aus',
#   'der',
#   'Pfanne',
#   'nehmen',
#   '5',
#   'Für',
#   'die',
#   'Soße',
#   '1',
#   '1',
#   '2',
#   'EL',
#   'Mehl',
#   'im',
#   'Bratensatz',
#   'anschwitzen',
#   'Mit',
#   'Wasser',
#   'Kalbsfond',
#   'und',
#   'Sahne',
#   'ablöschen',
#   'aufkochen',
#   'und',
#   'etwas',
#   'reduzieren',
#   'lassen',
#   'Mit',
#   'den',
#   'übrigen',
#   'Zutaten',
#   'abschmecken',
#   'Das',
#   'Johannisbeergelee',
#   'soll',
#   'sich',
#   'in',
#   'der',
#   'Soße',
#   'auflösen',
#   'Die',
#   'Hackbällchen',
#   'zur',
#   'Soße',
#   'geben',
#   'und',
#   'darin',
#   'wärmen',
#   'lassen',
#   '6',
#   'Ich',
#   'serviere',
#   'dazu',
#   'Kartoffelbrei',
#   'und',
#   'Preiselbeerenkonfitüre',
#   '7',
#   'Bei',
#   'den',
#   'angegebenen',
#   'Mengen',
#   'für',
#   'TL',
#   'und',
#   'EL',
#   'habe',
#   'ich',
#   'einen',
#   'Maßlöffel',
#   'verwendet'],
#  ['1',
#   'Mehl',
#   'in',
#   'eine',
#   'Schüssel',
#   'geben',
#   'und',
#   'eine',
#   'Mulde',
#   'formen',
#   'Darein',
#   'die',
#   'Hefe',
#   'krümeln',
#   'Salz',
#   'dazu',
#   'und',
#   'warmes',
#   'Wasser',
#   'unter',
#   'leichtem',
#   'rühren',
#   'ein',
#   'gießen',
#   'Die',
#   'Hefe',
#   'in',
#   'der',
#   'Mulde',
#   'mit',
#   'dem',
#   'Wasser',
#   'auflösen',
#   'abdecken',
#   'und',
#   '30',
#   'Minuten',
#   'ruhen',
#   'lassen',
#   'Dann',
#   'den',
#   'Rest',
#   'des',
#   'Mehls',
#   'mit',
#   'der',
#   'Hefe',
#   'zu',
#   'einem',
#   'Teig',
#   'verrühren',
#   'und',
#   'wieder',
#   '30',
#   'Minuten',
#   'abgedeckt',
#   'stehen',
#   'lassen',
#   '2',
#   'Jetzt',
#   'hat',
#   'sich',
#   'der',
#   'Teig',
#   'fast',
#   'verdoppelt',
#   'Mit',
#   'einem',
#   'Kochlöffel',
#   'wieder',
#   'rühren',
#   'und',
#   'schlagen',
#   'Dann',
#   'eine',
#   'Wurst',
#   'formen',
#   'und',
#   'in',
#   '10',
#   'gleiche',
#   'Stücke',
#   'schneiden',
#   'Brötchen',
#   'formen',
#   'Wasser',
#   'über',
#   'die',
#   'Brötchen',
#   'pinseln',
#   'werden',
#   'dann',
#   'schön',
#   'braun',
#   'Auf',
#   'Backpapier',
#   'bei',
#   '220',
#   'Grad',
#   '35',
#   'Minuten',
#   'backen',
#   'bis',
#   'die',
#   'Brötchen',
#   'eine',
#   'leckere',
#   'Farbe',
#   'haben'],
#  ['1',
#   'Die',
#   'Ciabatta',
#   'Brote',
#   'in',
#   'Scheiben',
#   'schneiden',
#   'Die',
#   'Tomaten',
#   'waschen',
#   'Strunk',
#   'entfernen',
#   'und',
#   'in',
#   'kleine',
#   'Würfel',
#   'schneiden',
#   'Die',
#   'Knoblauchzehe',
#   'abziehen',
#   'und',
#   'fein',
#   'hacken',
#   'Das',
#   'Basilikum',
#   'waschen',
#   'trocken',
#   'tupfen',
#   'und',
#   'grob',
#   'hacken',
#   '2',
#   'Den',
#   'Backofen',
#   'auf',
#   '200°C',
#   'vorheizen',
#   'Die',
#   'Vorbereiteten',
#   'Zutaten',
#   'in',
#   'einer',
#   'Schüssel',
#   'miteinander',
#   'vermischen',
#   'Etwas',
#   'Olivenöl',
#   'und',
#   'Balsamico',
#   'dazu',
#   'geben',
#   'und',
#   'verrühren',
#   'mit',
#   'Salz',
#   'und',
#   'Pfeffer',
#   'abschmecken',
#   'und',
#   'kurz',
#   'durchziehen',
#   'lassen',
#   'Die',
#   'Bruschetta',
#   'Masse',
#   'auf',
#   'die',
#   'Ciabatta',
#   'Scheiben',
#   'verteilen',
#   'und',
#   'für',
#   'ca',
#   '15',
#   'Minuten',
#   'in',
#   'den',
#   'Backofen',
#   'geben'],
#  ['1',
#   'Aus',
#   'den',
#   'Zutraten',
#   'für',
#   'den',
#   'Teig',
#   'einen',
#   'Rührteig',
#   'herstellen',
#   'Auf',
#   'ein',
#   'großes',
#   'gefettetes',
#   'Blech',
#   'streichen',
#   'ich',
#   'habe',
#   'für',
#   'die',
#   'Springform',
#   'nur',
#   'die',
#   'halbe',
#   'Menge',
#   'genommen',
#   'und',
#   'im',
#   'vorgeheizten',
#   'Backofen',
#   'bei',
#   '175°',
#   'C',
#   'etwa',
#   '20',
#   'Min',
#   'backen',
#   'Stäbchenprobe',
#   'Abkühlen',
#   'lassen',
#   '2',
#   'Aus',
#   'Milch',
#   'Grieß',
#   'und',
#   'Butter',
#   'einen',
#   'Grießbrei',
#   'kochen',
#   'Zucker',
#   'und',
#   'Kokosraspel',
#   'unterrühren',
#   'und',
#   'die',
#   'Masse',
#   'auf',
#   'den',
#   'Boden',
#   'streichen',
#   'Mit',
#   'dem',
#   'Schokoguss',
#   'überziehen',
#   'und',
#   'in',
#   'Riegel',
#   'schneiden'],
#  ['1',
#   'Butter',
#   'mit',
#   'Zucker',
#   'schaumig',
#   'rühren',
#   '2',
#   'Ei',
#   'mit',
#   'dem',
#   'Vanillezucker',
#   'verrühren',
#   'und',
#   'mit',
#   'der',
#   'Zuckerbutter',
#   'verrühren',
#   '3',
#   'Mehl',
#   'Backpulver',
#   'Kakao',
#   'und',
#   'Salz',
#   'mischen',
#   'sieben',
#   'und',
#   'unterheben',
#   '4',
#   'Sckokoladetafeln',
#   'grob',
#   'hacken',
#   'und',
#   'untermengen',
#   '5',
#   'Aus',
#   'dem',
#   'Teig',
#   'ca',
#   '16',
#   'kugeln',
#   'formen',
#   'und',
#   'auf',
#   'zwei',
#   'Backbleche',
#   'ca',
#   '1',
#   'cm',
#   'dick',
#   'plattdrücken',
#   'Wer',
#   'mag',
#   'kann',
#   'auch',
#   'noch',
#   'gehackte',
#   'Schokolade',
#   'drüberstreuen',
#   'und',
#   'leicht',
#   'andrücken',
#   'Oder',
#   'gehackte',
#   'geröstete',
#   'Nüsse',
#   'untermengen6',
#   'Umluft',
#   'ca',
#   '170',
#   'Grad',
#   'Backzeit',
#   'ca',
#   '10',
#   '12',
#   'Minuten',
#   'ja',
#   'nachdem',
#   'ob',
#   'sie',
#   'weich',
#   'oder',
#   'knusprig',
#   'werden',
#   'sollen',
#   'Nach',
#   'dem',
#   'Backen',
#   'gleich',
#   'mit',
#   'einem',
#   'Pfannenwender',
#   'auf',
#   'ein',
#   'Rost',
#   'legen',
#   'Sonst',
#   'backen',
#   'sie',
#   'noch',
#   'nach',
#   'Vorsicht',
#   'brechen',
#   'schnell'],
#  ...]

# %%
import re
def containsNumbers(string):
    return bool(re.search(r'\d', string))

for prep in preplist:
    prep = [w for w in prep if not containsNumbers(w)]

# %%
# Add all preparation steps and words to a single string
all_preps = ""
for prep in preplist:
    for word in prep:
        all_preps += word+" "
    all_preps += " \n \n "

# %%
prepfile = open('word_embeddings/preps.txt', 'w')
prepfile.write(all_preps)
# Out:
# 266260787

# %% [markdown]
# ## Train FastText models
#
# Now we can use the generated corpuses to train a FastText vector representations. For simplicity, we will trainwith the recommended default parameters and only adapt the number of threads to the 8 cores of the computer that has been used to train these models.

# %%
import fasttext 
title_model = fasttext.skipgram('word_embeddings/titles.txt', 'word_embeddings/title_model', thread=8)

# %%
import fasttext 
prep_model = fasttext.skipgram('word_embeddings/preps.txt', 'word_embeddings/prep_model', thread=8)

# %% [markdown]
# ## Load models
#
# In order to use the word embeddings in our implementation, we will need to load the models from their files after training them once.

# %%
import fasttext
title_model = fasttext.load_model('word_embeddings/title_model.bin')
prep_model = fasttext.load_model('word_embeddings/prep_model.bin')

# %% [markdown]
# ## Evaluation
#
# To choose between the two models that we have trained, we will evaluate their vectors for a chosen set of words that are either similar or different. Using the cosine similarity, we can measure how close or distant those words have been embedded in the model:

# %%
print("Similar words:")
print(title_model.cosine_similarity('Schinken', 'Salami'))
print(title_model.cosine_similarity('Filet', 'Steak'))
print(title_model.cosine_similarity('braten', 'backen'))
print(title_model.cosine_similarity('Fisch', 'Lachs'))
print(title_model.cosine_similarity('Paprika', 'Peperoni'))

print("\n Different words:")
print(title_model.cosine_similarity('Gurke', 'Leber'))
print(title_model.cosine_similarity('Salz', 'Kuchen'))
print(title_model.cosine_similarity('Chili', 'Milch'))
# Out:
# Similar words:
# 0.745956040107
# 0.683937946663
# 0.261322767337
# 0.650748116
# 0.735996235529
#
#  Different words:
# 0.340309920804
# 0.218356984463
# 0.414159474427

# %%
print("Similar words:")
print(prep_model.cosine_similarity('Schinken', 'Salami'))
print(prep_model.cosine_similarity('Filet', 'Steak'))
print(prep_model.cosine_similarity('braten', 'backen'))
print(prep_model.cosine_similarity('Fisch', 'Lachs'))
print(prep_model.cosine_similarity('Paprika', 'Peperoni'))

print("\n Different words:")
print(prep_model.cosine_similarity('Gurke', 'Leber'))
print(prep_model.cosine_similarity('Salz', 'Kuchen'))
print(prep_model.cosine_similarity('Chili', 'Milch'))
# Out:
# Similar words:
# 0.849591554368
# 0.665286910104
# 0.417357009985
# 0.7826654159
# 0.783189233043
#
#  Different words:
# 0.293415141586
# 0.00538366289464
# 0.265963553708

# %% [markdown]
# ### Result
#
# We can see that using the cosine similarity of word vectors, the model trained on the preparation steps rates similar words closer and different word more distant than the other model, thus is a better fit as a language model.
# Consecutively, we will use prep_model in further analysis.
